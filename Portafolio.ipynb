# %%
import pandas as pd
import pyodbc
import time 
import numpy as np
from datetime import datetime
print(pyodbc.drivers())
# Out:
# C:\Users\n1604989\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# ['SQL Server', 'SQL Server Native Client 11.0', 'ODBC Driver 13 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'ODBC Driver 17 for SQL Server']

# %%
# %run SetupDwhColombia.ipynb

# %%
setup_conn = ConectionSetup()
# Out:
# Enter User Name: n1604989
# Enter Password: ········
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][Administrador de controladores ODBC] No se encuentra el nombre del origen de datos y no se especificó ningún controlador predeterminado (0) (SQLDriverConnect)')
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-3-0f00aff7f296> in <module>
# ----> 1 setup_conn = ConectionSetup()
#
# <ipython-input-2-8b2127f8b70f> in __call__(cls, *args, **kwargs)
#       4     def __call__(cls, *args, **kwargs):
#       5         if cls not in cls._instances:
# ----> 6             cls._instances[cls] = super(Singleton, cls).__call__(*args, **kwargs)
#       7         return cls._instances[cls]
#
# <ipython-input-2-0ea25c58211d> in __init__(self)
#      15         self.con = None
#      16         self.user = getpass.getuser()
# ---> 17         self.get_connection()
#      18
#      19     def get_connection(self):
#
# <ipython-input-2-0ea25c58211d> in get_connection(self)
#      29             engine = sa.create_engine("mssql+pyodbc:///?odbc_connect={}".format(params))
#      30
# ---> 31             self.con = engine.connect()
#      32             self.con.autocommit = True
#      33         return self.con
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2261         """
#    2262
# -> 2263         return self._connection_cls(self, **kwargs)
#    2264
#    2265     @util.deprecated(
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     102                 connection
#     103                 if connection is not None
# --> 104                 else engine.raw_connection()
#     105             )
#     106             self.__transaction = None
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2367
#    2368         """
# -> 2369         return self._wrap_pool_connect(
#    2370             self.pool.unique_connection, _connection
#    2371         )
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     302
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#     306     def _create_connection(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\Program Files\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][Administrador de controladores ODBC] No se encuentra el nombre del origen de datos y no se especificó ningún controlador predeterminado (0) (SQLDriverConnect)')
# (Background on this error at: http://sqlalche.me/e/13/rvf5)

# %%
cnxn = setup_conn.con

# %%
ann_contable = 2021
mes_contable = 12
periodo = (ann_contable*100)+ mes_contable
print(periodo)
# Out:
# 202112

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# %%time
aseg_iaxis_query = f"""SELECT DISTINCT PERIODO_CONTABLE 
                            ,SUCURSAL_PROD
                            ,RAMO_PROD
                            ,POLIZA
                            ,CERTIFICADO
                            ,DOCUMENTO as ANEXO
                            ,ANEXO as DOCUMENTO
                            ,NRO_UNICO_ASEG AS SPERSON
                            ,TIPO_IDENTIFI_ASEG
                            ,NRO_IDENTIFI_ASEG
                            ,FI_VIG_ASEG AS FI_CERTIFICADO
                            ,FF_VIG_ASEG AS FF_CERTIFICADO                            
                     FROM PROD.DWH_POL_ASEG_H 
                     WHERE COD_PRODUCTO IN (104,105) AND ({periodo}-600)<=PERIODO_CONTABLE
                     AND PERIODO_CONTABLE<= {periodo} """

aseg_iaxis=pd.read_sql(aseg_iaxis_query,cnxn)
# Out:
# aseg_iaxis_query: 5.700382912158966 min

# %%
#removing spaces 
aseg_iaxis.RAMO_PROD = aseg_iaxis["RAMO_PROD"].str.strip()
aseg_iaxis.POLIZA = aseg_iaxis["POLIZA"].str.strip()
aseg_iaxis.CERTIFICADO = aseg_iaxis["CERTIFICADO"].str.strip()
aseg_iaxis.ANEXO = aseg_iaxis["ANEXO"].str.strip()
aseg_iaxis.DOCUMENTO = aseg_iaxis["DOCUMENTO"].str.strip()
aseg_iaxis.TIPO_IDENTIFI_ASEG = aseg_iaxis["TIPO_IDENTIFI_ASEG"].str.strip()
aseg_iaxis.NRO_IDENTIFI_ASEG = aseg_iaxis["NRO_IDENTIFI_ASEG"].str.strip()
aseg_iaxis.FI_CERTIFICADO = aseg_iaxis["FI_CERTIFICADO"].str.strip()
aseg_iaxis.FF_CERTIFICADO = aseg_iaxis["FF_CERTIFICADO"].str.strip()
aseg_iaxis.SUCURSAL_PROD = aseg_iaxis["SUCURSAL_PROD"].str.strip()
aseg_iaxis.dtypes
# Out:
# PERIODO_CONTABLE       Int64
# SUCURSAL_PROD         string
# RAMO_PROD             string
# POLIZA                string
# CERTIFICADO           string
# ANEXO                 string
# DOCUMENTO             string
# SPERSON                Int64
# TIPO_IDENTIFI_ASEG    string
# NRO_IDENTIFI_ASEG     string
# FI_CERTIFICADO        string
# FF_CERTIFICADO        string
# dtype: object

# %%
#deleting commas 
aseg_iaxis.FI_CERTIFICADO = aseg_iaxis.FI_CERTIFICADO.str[:8]
aseg_iaxis.FF_CERTIFICADO = aseg_iaxis.FF_CERTIFICADO.str[:8]
aseg_iaxis.head()
# Out:
#    PERIODO_CONTABLE SUCURSAL_PROD RAMO_PROD  POLIZA CERTIFICADO ANEXO  \
# 0            201608          20.0      6033  168727           0     1
# 1            201611          13.0      6046  149272         336     1
# 2            201906          27.0      6048  201424     1659867     7
# 3            202101         226.0      6048  293563     4886569     1
# 4            202101         226.0      6048  293563     5721948     2
#
#   DOCUMENTO   SPERSON TIPO_IDENTIFI_ASEG NRO_IDENTIFI_ASEG FI_CERTIFICADO  \
# 0         0    331712                  C          17095228       20160819
# 1         0    351120                  C          91260486       20161030
# 2         2   2348212                  C        1081183054       20190530
# 3         0  23858622                  C        1109494135       20200228
# 4         1  24662630                  C           4559294       20200812
#
#   FF_CERTIFICADO
# 0       20170819
# 1       20171030
# 2       20200530
# 3       20210228
# 4       20210812

# %%
#concatenating multiple columns
aseg_iaxis['LLAVE_DT']=aseg_iaxis['RAMO_PROD']+'-'+aseg_iaxis['POLIZA']+'-'+aseg_iaxis['CERTIFICADO']+'-'+aseg_iaxis['ANEXO']
aseg_iaxis['LLAVE_V']=aseg_iaxis['RAMO_PROD'] +'-'+aseg_iaxis['POLIZA']+'-'+aseg_iaxis['CERTIFICADO']+'-'+aseg_iaxis['FI_CERTIFICADO']+'-'+aseg_iaxis['FF_CERTIFICADO']
aseg_iaxis.head()
# Out:
#    PERIODO_CONTABLE SUCURSAL_PROD RAMO_PROD  POLIZA CERTIFICADO ANEXO  \
# 0            201608          20.0      6033  168727           0     1
# 1            201611          13.0      6046  149272         336     1
# 2            201906          27.0      6048  201424     1659867     7
# 3            202101         226.0      6048  293563     4886569     1
# 4            202101         226.0      6048  293563     5721948     2
#
#   DOCUMENTO   SPERSON TIPO_IDENTIFI_ASEG NRO_IDENTIFI_ASEG FI_CERTIFICADO  \
# 0         0    331712                  C          17095228       20160819
# 1         0    351120                  C          91260486       20161030
# 2         2   2348212                  C        1081183054       20190530
# 3         0  23858622                  C        1109494135       20200228
# 4         1  24662630                  C           4559294       20200812
#
#   FF_CERTIFICADO               LLAVE_DT                                LLAVE_V
# 0       20170819        6033-168727-0-1        6033-168727-0-20160819-20170819
# 1       20171030      6046-149272-336-1      6046-149272-336-20161030-20171030
# 2       20200530  6048-201424-1659867-7  6048-201424-1659867-20190530-20200530
# 3       20210228  6048-293563-4886569-1  6048-293563-4886569-20200228-20210228
# 4       20210812  6048-293563-5721948-2  6048-293563-5721948-20200812-20210812

# %%
#casting to datetime
#aseg_iaxis_h.FI_CERTIFICADO = pd.to_datetime(aseg_iaxis_h["FI_CERTIFICADO"], format= '%Y-%m-%d', errors = "coerce")
#aseg_iaxis_h.FF_CERTIFICADO = pd.to_datetime(aseg_iaxis_h["FF_CERTIFICADO"], format= '%Y-%m-%d', errors = "coerce")
#aseg_iaxis_h.head()

# %%
# %%time
aseg_as400_query = f'''SELECT DISTINCT PERIODO_CONTABLE
                              ,SUCURSAL_PROD
                              ,RAMO_PROD
                              ,POLIZA
                              ,CERTIFICADO
                              ,DOCUMENTO
                              ,ANEXO
                              /*,. AS SPERSON*/
                              ,TIPO_IDENTIFI_ASEG
                              /*,NRO_IDENTIFI_ASEG AS NRO_ID*/
                              ,FI_VIG_ASEG AS FI_CERTIFICADO
                              ,FF_VIG_ASEG AS FF_CERTIFICADO
              FROM PROD.DWH_POL_ASEG_H
              WHERE ({periodo}-600)<=PERIODO_CONTABLE
              AND PERIODO_CONTABLE<= {periodo}
              AND RAMO_PROD IN ('AL','AT','AU','AW','AX','CT','ET','LM','LO','ME','MO','MT','MU','MW','PE','PM','PO','TO','TP','AWL','TS','TT','TU','MF','LF')
              ORDER BY RAMO_PROD, POLIZA, CERTIFICADO, DOCUMENTO'''
#cambiar read_sql_query, + dicc
aseg_as400_h = pd.read_sql(aseg_as400_query,cnxn)
# Out:
# aseg_as400_query: 1.8523198088010153 min

# %%
#removing spaces 
aseg_as400.RAMO_PROD = aseg_as400["RAMO_PROD"].str.strip()
aseg_as400.POLIZA = aseg_as400["POLIZA"].str.strip()
aseg_as400.CERTIFICADO = aseg_as400["CERTIFICADO"].str.strip()
aseg_as400.ANEXO = aseg_as400["CERTIFICADO"].str.strip()
aseg_as400.DOCUMENTO = aseg_as400["DOCUMENTO"].str.strip()
aseg_as400.FI_CERTIFICADO = aseg_as400["FI_CERTIFICADO"].str.strip()
aseg_as400.FF_CERTIFICADO = aseg_as400["FF_CERTIFICADO"].str.strip()
aseg_as400.TIPO_IDENTIFI_ASEG = aseg_as400["TIPO_IDENTIFI_ASEG"].str.strip()
aseg_as400.SUCURSAL_PROD = aseg_as400["SUCURSAL_PROD"].str.strip()
aseg_as400.head()
# Out:
#    PERIODO_CONTABLE SUCURSAL_PROD RAMO_PROD POLIZA CERTIFICADO DOCUMENTO  \
# 0            201605            11        AT   8796         114      1201
# 1            201609            11        AT   8796         149      1001
# 2            201607            11        AT   8796         161       801
# 3            201607            11        AT   8796         161       901
# 4            201607            11        AT   8796         161       901
#
#   ANEXO TIPO_IDENTIFI_ASEG FI_CERTIFICADO FF_CERTIFICADO
# 0   114                  N       20151103       20160426
# 1   149                  C       20151103       20160531
# 2   161                  C       20151103       20161103
# 3   161                  C       20151103       20161103
# 4   161                  C       20160617       20161103

# %%
#deleting commas 
aseg_as400.FI_CERTIFICADO = aseg_as400.FI_CERTIFICADO.str[:8]
aseg_as400.FF_CERTIFICADO = aseg_as400.FF_CERTIFICADO.str[:8]
aseg_as400.head()
# Out:
#    PERIODO_CONTABLE SUCURSAL_PROD RAMO_PROD POLIZA CERTIFICADO DOCUMENTO  \
# 0            201605            11        AT   8796         114      1201
# 1            201609            11        AT   8796         149      1001
# 2            201607            11        AT   8796         161       801
# 3            201607            11        AT   8796         161       901
# 4            201607            11        AT   8796         161       901
#
#   ANEXO TIPO_IDENTIFI_ASEG FI_CERTIFICADO FF_CERTIFICADO
# 0   114                  N       20151103       20160426
# 1   149                  C       20151103       20160531
# 2   161                  C       20151103       20161103
# 3   161                  C       20151103       20161103
# 4   161                  C       20160617       20161103

# %%
aseg_as400['LLAVE_DT']=aseg_as400['RAMO_PROD']+'-'+aseg_as400['POLIZA']+'-'+aseg_as400['CERTIFICADO']+'-'+aseg_as400['DOCUMENTO']
aseg_as400['LLAVE_V']=aseg_as400['RAMO_PROD']+'-'+aseg_as400['POLIZA']+'-'+aseg_as400['CERTIFICADO']+'-'+aseg_as400['FI_CERTIFICADO']+'-'+aseg_as400['FF_CERTIFICADO']
aseg_as400.head()
# Out:
#    PERIODO_CONTABLE SUCURSAL_PROD RAMO_PROD POLIZA CERTIFICADO DOCUMENTO  \
# 0            201605            11        AT   8796         114      1201
# 1            201609            11        AT   8796         149      1001
# 2            201607            11        AT   8796         161       801
# 3            201607            11        AT   8796         161       901
# 4            201607            11        AT   8796         161       901
#
#   ANEXO TIPO_IDENTIFI_ASEG FI_CERTIFICADO FF_CERTIFICADO          LLAVE_DT  \
# 0   114                  N       20151103       20160426  AT-8796-114-1201
# 1   149                  C       20151103       20160531  AT-8796-149-1001
# 2   161                  C       20151103       20161103   AT-8796-161-801
# 3   161                  C       20151103       20161103   AT-8796-161-901
# 4   161                  C       20160617       20161103   AT-8796-161-901
#
#                          LLAVE_V
# 0  AT-8796-114-20151103-20160426
# 1  AT-8796-149-20151103-20160531
# 2  AT-8796-161-20151103-20161103
# 3  AT-8796-161-20151103-20161103
# 4  AT-8796-161-20160617-20161103

# %%
#casting to datetime
##aseg_as400_h.FI_CERTIFICADO = pd.to_datetime(aseg_as400_h["FI_CERTIFICADO"], format= '%Y-%m-%d', errors = "coerce")
##aseg_as400_h.FF_CERTIFICADO = pd.to_datetime(aseg_as400_h["FF_CERTIFICADO"], format= '%Y-%m-%d', errors = "coerce")
##aseg_as400_h.head()

# %%
#first_concat
aseg_id=pd.concat([aseg_iaxis,aseg_as400],ignore_index=True)
aseg_id.dtypes
# Out:
# PERIODO_CONTABLE       Int64
# SUCURSAL_PROD         string
# RAMO_PROD             string
# POLIZA                string
# CERTIFICADO           string
# ANEXO                 string
# DOCUMENTO             string
# SPERSON                Int64
# TIPO_IDENTIFI_ASEG    string
# NRO_IDENTIFI_ASEG     string
# FI_CERTIFICADO        string
# FF_CERTIFICADO        string
# LLAVE_DT              string
# LLAVE_V               string
# dtype: object

# %%
aseg_id=aseg_id.sort_values(['LLAVE_DT','ANEXO','DOCUMENTO','PERIODO_CONTABLE','TIPO_IDENTIFI_ASEG','NRO_IDENTIFI_ASEG','FI_CERTIFICADO','FF_CERTIFICADO'],ascending=(True,True,True,True,True,True,True,True))
aseg_id.head()
# Out:
#          PERIODO_CONTABLE SUCURSAL_PROD RAMO_PROD  POLIZA CERTIFICADO ANEXO  \
# 6434604            201605          13.0      6031  100000           0     2
# 2195239            201605          13.0      6031  100000           0     3
# 4742980            201605          37.0      6031  100003           0     2
# 3075392            201701          37.0      6031  100003           0     4
# 7248220            201705          37.0      6031  100003           0     5
#
#         DOCUMENTO  SPERSON TIPO_IDENTIFI_ASEG NRO_IDENTIFI_ASEG  \
# 6434604         0   565704                  C          37514526
# 2195239         0   565704                  C          37514526
# 4742980         0   564368                  C          41691171
# 3075392         1   564368                  C          41691171
# 7248220         1   564368                  C          41691171
#
#         FI_CERTIFICADO FF_CERTIFICADO         LLAVE_DT  \
# 6434604       20160507       20170507  6031-100000-0-2
# 2195239       20160507       20170507  6031-100000-0-3
# 4742980       20160506       20170506  6031-100003-0-2
# 3075392       20170107       20170506  6031-100003-0-4
# 7248220       20170506       20180506  6031-100003-0-5
#
#                                  LLAVE_V
# 6434604  6031-100000-0-20160507-20170507
# 2195239  6031-100000-0-20160507-20170507
# 4742980  6031-100003-0-20160506-20170506
# 3075392  6031-100003-0-20170107-20170506
# 7248220  6031-100003-0-20170506-20180506

# %%
#setting ranking by "LLAVE_DT"
aseg_id['RANK']=aseg_id.groupby('LLAVE_DT').cumcount() +1
aseg_id.head()
# Out:
#          PERIODO_CONTABLE SUCURSAL_PROD RAMO_PROD  POLIZA CERTIFICADO ANEXO  \
# 6434604            201605          13.0      6031  100000           0     2
# 2195239            201605          13.0      6031  100000           0     3
# 4742980            201605          37.0      6031  100003           0     2
# 3075392            201701          37.0      6031  100003           0     4
# 7248220            201705          37.0      6031  100003           0     5
#
#         DOCUMENTO  SPERSON TIPO_IDENTIFI_ASEG NRO_IDENTIFI_ASEG  \
# 6434604         0   565704                  C          37514526
# 2195239         0   565704                  C          37514526
# 4742980         0   564368                  C          41691171
# 3075392         1   564368                  C          41691171
# 7248220         1   564368                  C          41691171
#
#         FI_CERTIFICADO FF_CERTIFICADO         LLAVE_DT  \
# 6434604       20160507       20170507  6031-100000-0-2
# 2195239       20160507       20170507  6031-100000-0-3
# 4742980       20160506       20170506  6031-100003-0-2
# 3075392       20170107       20170506  6031-100003-0-4
# 7248220       20170506       20180506  6031-100003-0-5
#
#                                  LLAVE_V  RANK
# 6434604  6031-100000-0-20160507-20170507     1
# 2195239  6031-100000-0-20160507-20170507     1
# 4742980  6031-100003-0-20160506-20170506     1
# 3075392  6031-100003-0-20170107-20170506     1
# 7248220  6031-100003-0-20170506-20180506     1

# %%
aseg_id_count=aseg_id.groupby('LLAVE_DT').count()
aseg_id_count=aseg_id_count['RANK']
aseg_id_count.head()
# Out:
# LLAVE_DT
# 6031-100000-0-2    1
# 6031-100000-0-3    1
# 6031-100003-0-2    1
# 6031-100003-0-4    1
# 6031-100003-0-5    1
# Name: RANK, dtype: int64

# %%
aseg_id=pd.merge(aseg_id,aseg_id_count,on=['LLAVE_DT'],how='left')
aseg_id.dtypes
# Out:
# PERIODO_CONTABLE       Int64
# SUCURSAL_PROD         string
# RAMO_PROD             string
# POLIZA                string
# CERTIFICADO           string
# ANEXO                 string
# DOCUMENTO             string
# SPERSON                Int64
# TIPO_IDENTIFI_ASEG    string
# NRO_IDENTIFI_ASEG     string
# FI_CERTIFICADO        string
# FF_CERTIFICADO        string
# LLAVE_DT              string
# LLAVE_V               string
# RANK_x                 int64
# RANK_y                 int64
# dtype: object

# %%
aseg_id=aseg_id[aseg_id['RANK_x']==aseg_id['RANK_y']]
len(aseg_id)
# Out:
# 7919228

# %%
aseg_id=aseg_id.drop(['RANK_x','RANK_y'],axis=1)
aseg_id.dtypes
# Out:
# PERIODO_CONTABLE       Int64
# SUCURSAL_PROD         string
# RAMO_PROD             string
# POLIZA                string
# CERTIFICADO           string
# ANEXO                 string
# DOCUMENTO             string
# SPERSON                Int64
# TIPO_IDENTIFI_ASEG    string
# NRO_IDENTIFI_ASEG     string
# FI_CERTIFICADO        string
# FF_CERTIFICADO        string
# LLAVE_DT              string
# LLAVE_V               string
# dtype: object

# %%
#aseg_id_h.to_csv("aseg_dt.csv")

# %%
# %%time
autos_iaxis_query = f'''SELECT RAMO_PROD
                        ,POLIZA
                        ,CERTIFICADO
                        ,DOCUMENTO
                        ,ANEXO
                        ,NRO_PLACA
                        ,NRO_CHASIS
                        ,COD_MARCA
                        ,COD_CLASE
                        ,COD_TIPO
                        ,PESO
                        ,ANN_MODELO
                        ,CILINDRAJE
                        ,CAPACI_OCUPANTES
                        ,IND_ACCESORIOS
                        ,VR_ASEG_ACCESORIOS
                        ,VR_ASEG_CASCO
              FROM DT.DWH_DT_AUT_AUTOS 
              WHERE COD_PRODUCTO IN (104,105)'''
autos_iaxis=pd.read_sql_query(autos_iaxis_query,cnxn,dtype={'RAMO_PROD':'string'
                                                             ,'POLIZA':'string'
                                                             ,'CERTIFICADO':'string'
                                                             ,'DOCUMENTO':'string'
                                                             ,'ANEXO':'string'
                                                             ,'NRO_PLACA':'string'
                                                             ,'NRO_CHASIS':'string'
                                                             ,'IND_ACCESORIOS':'string'
                                                             ,'COD_MARCA':'Int64'
                                                             ,'COD_CLASE':'Int64'
                                                             ,'COD_TIPO':'Int64'
                                                             ,'PESO':'Int64'
                                                             ,'ANN_MODELO':'Int64'
                                                             ,'CILINDRAJE':'Int64'
                                                             ,'CAPACI_OCUPANTES':'Int64'
                                                             ,'VR_ASEG_ACCESORIOS':'float64'
                                                             ,'VR_ASEG_CASCO':'float64'})
# Out:
# autos_iaxis_query: 4.370258967081706 min

# %%
autos_iaxis.RAMO_PROD = autos_iaxis['RAMO_PROD'].str.strip()
autos_iaxis.POLIZA = autos_iaxis['POLIZA'].str.strip()
autos_iaxis.CERTIFICADO = autos_iaxis['CERTIFICADO'].str.strip()
autos_iaxis.DOCUMENTO = autos_iaxis['DOCUMENTO'].str.strip()
autos_iaxis.ANEXO = autos_iaxis['ANEXO'].str.strip()
autos_iaxis.NRO_PLACA = autos_iaxis['NRO_PLACA'].str.strip()
autos_iaxis.NRO_CHASIS = autos_iaxis['NRO_CHASIS'].str.strip()
autos_iaxis.IND_ACCESORIOS = autos_iaxis['IND_ACCESORIOS'].str.strip()

# %%
autos_iaxis['LLAVE_DT']=autos_iaxis['RAMO_PROD']+'-'+autos_iaxis['POLIZA']+'-'+autos_iaxis['CERTIFICADO']+'-'+autos_iaxis['DOCUMENTO']
autos_iaxis.head()
# Out:
#   RAMO_PROD POLIZA CERTIFICADO DOCUMENTO ANEXO NRO_PLACA       NRO_CHASIS  \
# 0      6031   3445           0         1     0    TL7613  JSACHAS1STL7613
# 1      6031   3445           0         2     1    TL7613  JSACHAS1STL7613
# 2      6031   3445           0         4     2    TL7613  JSACHAS1STL7613
# 3      6031   3633           0         1     0    TLI845       JSA1236545
# 4      6031   3633           0         2     0    TLI845       JSA1236545
#
#    COD_MARCA  COD_CLASE  COD_TIPO  PESO  ANN_MODELO  CILINDRAJE  \
# 0         16          1       100     0        2014        1400
# 1         16          1       100     0        2014        1400
# 2         16          1       100     0        2014        1400
# 3         16          1        73     0        2004        1600
# 4         16          1        73     0        2004        1600
#
#    CAPACI_OCUPANTES IND_ACCESORIOS  VR_ASEG_ACCESORIOS  VR_ASEG_CASCO  \
# 0                 5              S            150000.0     24700000.0
# 1                 5              S            150000.0     24700000.0
# 2                 5              S            150000.0     24700000.0
# 3                 5                                0.0     11400000.0
# 4                 5                                0.0     11400000.0
#
#         LLAVE_DT
# 0  6031-3445-0-1
# 1  6031-3445-0-2
# 2  6031-3445-0-4
# 3  6031-3633-0-1
# 4  6031-3633-0-2

# %%
autos_iaxis=autos_iaxis.sort_values(['LLAVE_DT','NRO_PLACA','DOCUMENTO'],ascending=(True,True,True))
autos_iaxis.head()
# Out:
#        RAMO_PROD  POLIZA CERTIFICADO DOCUMENTO ANEXO NRO_PLACA  \
# 435637      6031  100000           0         1     0
# 435638      6031  100000           0         2     0    RLR984
# 435639      6031  100000           0         3     0    RLR984
# 454392      6031  100003           0         1     0
# 454393      6031  100003           0         2     0    CDN702
#
#                NRO_CHASIS  COD_MARCA  COD_CLASE  COD_TIPO  PESO  ANN_MODELO  \
# 435637                             0          0         0     0        <NA>
# 435638  3GNAL7EC1BS679545         16          6       213     0        2011
# 435639  3GNAL7EC1BS679545         16          6       213     0        2011
# 454392                             0          0         0     0        <NA>
# 454393  9FCBK456580102489         56          2       422     0        2008
#
#         CILINDRAJE  CAPACI_OCUPANTES IND_ACCESORIOS  VR_ASEG_ACCESORIOS  \
# 435637           0                 0              S                 0.0
# 435638        2384                 5              S                 0.0
# 435639        2384                 5              S                 0.0
# 454392           0                 0              S                 0.0
# 454393        1600                 5              S                 0.0
#
#         VR_ASEG_CASCO         LLAVE_DT
# 435637     40500000.0  6031-100000-0-1
# 435638     44700000.0  6031-100000-0-2
# 435639     44700000.0  6031-100000-0-3
# 454392     24100000.0  6031-100003-0-1
# 454393     22900000.0  6031-100003-0-2

# %%
autos_iaxis['RANK']=autos_iaxis.groupby('LLAVE_DT').cumcount() +1
autos_iaxis.head()
# Out:
#        RAMO_PROD  POLIZA CERTIFICADO DOCUMENTO ANEXO NRO_PLACA  \
# 435637      6031  100000           0         1     0
# 435638      6031  100000           0         2     0    RLR984
# 435639      6031  100000           0         3     0    RLR984
# 454392      6031  100003           0         1     0
# 454393      6031  100003           0         2     0    CDN702
#
#                NRO_CHASIS  COD_MARCA  COD_CLASE  COD_TIPO  PESO  ANN_MODELO  \
# 435637                             0          0         0     0        <NA>
# 435638  3GNAL7EC1BS679545         16          6       213     0        2011
# 435639  3GNAL7EC1BS679545         16          6       213     0        2011
# 454392                             0          0         0     0        <NA>
# 454393  9FCBK456580102489         56          2       422     0        2008
#
#         CILINDRAJE  CAPACI_OCUPANTES IND_ACCESORIOS  VR_ASEG_ACCESORIOS  \
# 435637           0                 0              S                 0.0
# 435638        2384                 5              S                 0.0
# 435639        2384                 5              S                 0.0
# 454392           0                 0              S                 0.0
# 454393        1600                 5              S                 0.0
#
#         VR_ASEG_CASCO         LLAVE_DT  RANK
# 435637     40500000.0  6031-100000-0-1     1
# 435638     44700000.0  6031-100000-0-2     1
# 435639     44700000.0  6031-100000-0-3     1
# 454392     24100000.0  6031-100003-0-1     1
# 454393     22900000.0  6031-100003-0-2     1

# %%
autos_iaxis_count=autos_iaxis.groupby('LLAVE_DT').count()
autos_iaxis_count=autos_iaxis_count['RANK']
autos_iaxis_count.head()
# Out:
# LLAVE_DT
# 6031-100000-0-1    1
# 6031-100000-0-2    1
# 6031-100000-0-3    1
# 6031-100003-0-1    1
# 6031-100003-0-2    1
# Name: RANK, dtype: int64

# %%
autos_iaxis=pd.merge(autos_iaxis,autos_iaxis_count,on=['LLAVE_DT'],how='left')
len(autos_iaxis)
# Out:
# 11948777

# %%
autos_iaxis=autos_iaxis[autos_iaxis['RANK_x']==autos_iaxis['RANK_y']]
len(autos_iaxis)
# Out:
# 4571740

# %%
autos_iaxis=autos_iaxis[autos_iaxis.NRO_PLACA.values!= '']
len(autos_iaxis)
# Out:
# 4539783

# %%
#acaca
autos_iaxis['IND_ACCESORIOS']=np.where(autos_iaxis.IND_ACCESORIOS.values=='S','S',autos_iaxis['IND_ACCESORIOS'])
autos_iaxis['IND_ACCESORIOS']=np.where(autos_iaxis.IND_ACCESORIOS.values!='S','N',autos_iaxis['IND_ACCESORIOS'])
# Out:
# 4539783

# %%
autos_iaxis=autos_iaxis.drop(['RANK_x','RANK_y','RAMO_PROD','POLIZA','CERTIFICADO','ANEXO','DOCUMENTO'],axis=1)
autos_iaxis.head()
# Out:
#   NRO_PLACA         NRO_CHASIS  COD_MARCA  COD_CLASE  COD_TIPO  PESO  \
# 1    RLR984  3GNAL7EC1BS679545         16          6       213     0
# 2    RLR984  3GNAL7EC1BS679545         16          6       213     0
# 4    CDN702  9FCBK456580102489         56          2       422     0
# 5    UUL857  3N1CN7AD5ZK151997         64          1       218     0
# 6    UUL857  3N1CN7AD5ZK151997         64          1       218     0
#
#    ANN_MODELO  CILINDRAJE  CAPACI_OCUPANTES IND_ACCESORIOS  \
# 1        2011        2384                 5              S
# 2        2011        2384                 5              S
# 4        2008        1600                 5              S
# 5        2016        1598                 5              S
# 6        2016        1598                 5              S
#
#    VR_ASEG_ACCESORIOS  VR_ASEG_CASCO         LLAVE_DT
# 1                 0.0     44700000.0  6031-100000-0-2
# 2                 0.0     44700000.0  6031-100000-0-3
# 4                 0.0     22900000.0  6031-100003-0-2
# 5            200000.0     42100000.0  6031-100003-0-4
# 6            200000.0     42100000.0  6031-100003-0-5

# %%
# %%time
polizas_iaxis_query = f"""SELECT PERIODO_CONTABLE
                          ,SSEGURO
                          ,SUCURSAL_PROD
                          ,RAMO_PROD
                          ,POLIZA
                          ,CERTIFICADO
                          ,DOCUMENTO
                          ,ANEXO
                          ,RECIBO
                          ,FI_POLIZA_MATRIZ
                          ,FI_CERTIFICADO
                          ,FF_CERTIFICADO
                          ,FI_ANEXO
                          ,FF_ANEXO
                          ,FI_DOCUMENTO
                          ,FF_DOCUMENTO
                          ,FI_VIGENCIA_ANT
                          ,FECHA_EXPE
                          ,TIPO_TRANSAC
                          ,FREC_PAGO
                          ,NRO_UNICO_TOMADOR
                          ,TIPO_IDENTIFI_TOM
                          ,NRO_IDENTIFI_TOM
                          ,INTERMEDIARIO_LIDE
                          ,CANAL
                          ,SEGMENTO
                          ,VR_ASEG_POLIZA
                          ,VR_PRIMA_MN_ORIG
                          ,VR_PRIMA_PESOS
                          ,VR_PRIMA_ANUAL
                          ,COD_DEPARTAMENTO
                          ,COD_CIUDAD
                          ,LLAVE
                          ,'IAXIS' AS ORIGEN
          FROM PROD.DWH_POLIZAS_H 
          WHERE ({periodo}-600)<=PERIODO_CONTABLE
          AND PERIODO_CONTABLE<= {periodo}
          /*ANNO_CONTABLE=&ANO AND MES_CONTABLE=&MES*/ 
          AND COD_PRODUCTO IN (104,105)"""
polizas_iaxis_h = pd.read_sql_query(polizas_iaxis_query,cnxn,dtype={"PERIODO_CONTABLE":"Int64","SSEGURO":"Int64","SUCURSAL_PROD":"string","RAMO_PROD":"string","POLIZA":"string","CERTIFICADO":"string","DOCUMENTO":"string","ANEXO":"string","RECIBO":"Int64","FI_POLIZA_MATRIZ":"string","FI_CERTIFICADO":"string","FF_CERTIFICADO":"string","FI_ANEXO":"string","FF_ANEXO":"string","FI_DOCUMENTO":"string","FF_DOCUMENTO":"string","FI_VIGENCIA_ANT":"string","FECHA_EXPE":"string","TIPO_TRANSAC":"Int64","FREC_PAGO":"Int64","NRO_UNICO_TOMADOR":"Int64","TIPO_IDENTIFI_TOM":"string","NRO_IDENTIFI_TOM":"string","INTERMEDIARIO_LIDE":"Int64","CANAL":"string","SEGMENTO":"Int64","VR_ASEG_POLIZA":"float64","VR_PRIMA_MN_ORIG":"float64","VR_PRIMA_PESOS":"float64","VR_PRIMA_ANUAL":"float64","COD_DEPARTAMENTO":"string","COD_CIUDAD":"string","LLAVE":"string","ORIGEN":"string"})
# Out:
# polizas_iaxis_query: 8.285781697432201 min

# %%
polizas_iaxis.RAMO_PROD = polizas_iaxis['RAMO_PROD'].str.strip()
polizas_iaxis.POLIZA = polizas_iaxis['POLIZA'].str.strip()
polizas_iaxis.CERTIFICADO = polizas_iaxis['CERTIFICADO'].str.strip()
polizas_iaxis.DOCUMENTO = polizas_iaxis['DOCUMENTO'].str.strip()
polizas_iaxis.ANEXO = polizas_iaxis['ANEXO'].str.strip()
polizas_iaxis.FI_CERTIFICADO = polizas_iaxis['FI_CERTIFICADO'].str.strip()
polizas_iaxis.FF_CERTIFICADO = polizas_iaxis['FF_CERTIFICADO'].str.strip()
polizas_iaxis.SUCURSAL_PROD = polizas_iaxis['SUCURSAL_PROD'].str.strip()
polizas_iaxis.TIPO_IDENTIFI_TOM = polizas_iaxis['TIPO_IDENTIFI_TOM'].str.strip()
polizas_iaxis.NRO_IDENTIFI_TOM = polizas_iaxis['NRO_IDENTIFI_TOM'].str.strip()
polizas_iaxis.CANAL = polizas_iaxis['CANAL'].str.strip()
polizas_iaxis.COD_DEPARTAMENTO = polizas_iaxis['COD_DEPARTAMENTO'].str.strip()
polizas_iaxis.COD_CIUDAD = polizas_iaxis['COD_CIUDAD'].str.strip()
polizas_iaxis.LLAVE = polizas_iaxis['LLAVE'].str.strip()

# %%
polizas_iaxis.FI_CERTIFICADO=polizas_iaxis.FI_CERTIFICADO.str[:8]
polizas_iaxis.FF_CERTIFICADO=polizas_iaxis.FF_CERTIFICADO.str[:8]

# %%
polizas_iaxis['LLAVE_DT']=polizas_iaxis['RAMO_PROD'] +'-'+polizas_iaxis['POLIZA']+'-'+polizas_iaxis['CERTIFICADO']+'-'+polizas_iaxis['ANEXO']
polizas_iaxis['LLAVE_V']=polizas_iaxis['RAMO_PROD']+'-'+polizas_iaxis['POLIZA']+'-'+polizas_iaxis['CERTIFICADO']+'-'+polizas_iaxis['FI_CERTIFICADO']+'-'+polizas_iaxis['FF_CERTIFICADO']

# %%
'''polizas_iaxis_h["FI_CERTIFICADO"] = pd.to_datetime(polizas_iaxis_h["FI_CERTIFICADO"], format= '%Y-%m-%d', errors = "coerce")
polizas_iaxis_h["FF_CERTIFICADO"] = pd.to_datetime(polizas_iaxis_h["FF_CERTIFICADO"], format= '%Y-%m-%d', errors = "coerce")
polizas_iaxis_h["FI_ANEXO"] = pd.to_datetime(polizas_iaxis_h["FI_ANEXO"], format= '%Y-%m-%d', errors = "coerce")
polizas_iaxis_h["FF_ANEXO"] = pd.to_datetime(polizas_iaxis_h["FF_ANEXO"], format= '%Y-%m-%d', errors = "coerce")
polizas_iaxis_h["FI_DOCUMENTO"] = pd.to_datetime(polizas_iaxis_h["FI_DOCUMENTO"], format= '%Y-%m-%d', errors = "coerce")
polizas_iaxis_h["FF_DOCUMENTO"] = pd.to_datetime(polizas_iaxis_h["FF_DOCUMENTO"], format= '%Y-%m-%d', errors = "coerce")
polizas_iaxis_h["FI_POLIZA_MATRIZ"] = pd.to_datetime(polizas_iaxis_h["FI_POLIZA_MATRIZ"], format= '%Y-%m-%d', errors = "coerce")
polizas_iaxis_h["FI_VIGENCIA_ANT"] = pd.to_datetime(polizas_iaxis_h["FI_VIGENCIA_ANT"], format= '%Y-%m-%d', errors = "coerce")
polizas_iaxis_h["FECHA_EXPE"] = pd.to_datetime(polizas_iaxis_h["FECHA_EXPE"], format= '%Y-%m-%d', errors = "coerce")
polizas_iaxis_h.dtypes'''

# %%
polizas_iaxis=polizas_iaxis.sort_values('LLAVE_DT',ascending=True)
# Out:
# 9752647

# %%
# %%time
pol_aux_query=f'''SELECT DISTINCT LLAVE
                                 ,COD_MODALIDAD AS TIPO_RIESGO
                  FROM PROD.DWH_POLIZAS_H
                  WHERE RAMO_PROD= 900753''''
pol_aux=pd.read_sql_query(pol_aux_query,cnxn,dtype={'LLAVE':'string','TIPO_RIESGO':'Int32'})
# Out:
# pol_aux_query: 1.4037570794423422 sec

# %%
pol_aux.LLAVE=pol_aux['LLAVE'].str.strip()
# Out:
#                      LLAVE  TIPO_RIESGO
# 0   0011535003000146036836            1
# 1  00179454890001128654829            1
# 2  00168286700001130599554            1
# 3  00258934440001170918310            1
# 4  00268326260001173495889            1

# %%
polizas_iaxis=pd.merge(polizas_iaxis,autos_iaxis,on=['LLAVE_DT'],how='left')
# Out:
# PERIODO_CONTABLE        Int64
# SSEGURO                 Int64
# SUCURSAL_PROD          string
# RAMO_PROD              string
# POLIZA                 string
# CERTIFICADO            string
# DOCUMENTO              string
# ANEXO                  string
# RECIBO                  Int64
# FI_POLIZA_MATRIZ       string
# FI_CERTIFICADO         string
# FF_CERTIFICADO         string
# FI_ANEXO               string
# FF_ANEXO               string
# FI_DOCUMENTO           string
# FF_DOCUMENTO           string
# FI_VIGENCIA_ANT        string
# FECHA_EXPE             string
# TIPO_TRANSAC            Int64
# FREC_PAGO               Int64
# NRO_UNICO_TOMADOR       Int64
# TIPO_IDENTIFI_TOM      string
# NRO_IDENTIFI_TOM       string
# INTERMEDIARIO_LIDE      Int64
# CANAL                  string
# SEGMENTO                Int64
# VR_ASEG_POLIZA        float64
# VR_PRIMA_MN_ORIG      float64
# VR_PRIMA_PESOS        float64
# VR_PRIMA_ANUAL        float64
# COD_DEPARTAMENTO       string
# COD_CIUDAD             string
# LLAVE                  string
# ORIGEN                 string
# LLAVE_DT               string
# LLAVE_V                string
# NRO_PLACA              string
# NRO_CHASIS             string
# COD_MARCA               Int64
# COD_CLASE               Int64
# COD_TIPO                Int64
# PESO                    Int64
# ANN_MODELO              Int64
# CILINDRAJE              Int64
# CAPACI_OCUPANTES        Int64
# IND_ACCESORIOS         string
# VR_ASEG_ACCESORIOS    float64
# VR_ASEG_CASCO         float64
# dtype: object

# %%
polizas_iaxis=pd.merge(polizas_iaxis,pol_aux,on=['LLAVE'],how='left')
# Out:
#    PERIODO_CONTABLE  SSEGURO SUCURSAL_PROD RAMO_PROD  POLIZA CERTIFICADO  \
# 0            201605   857251            13      6031  100000           0
# 1            201605   857251            13      6031  100000           0
# 2            201605   839600            37      6031  100003           0
# 3            201804   839600            37      6031  100003           0
# 4            201705   839600            37      6031  100003           0
#
#   DOCUMENTO ANEXO   RECIBO FI_POLIZA_MATRIZ FI_CERTIFICADO FF_CERTIFICADO  \
# 0         2     0  2554383         20150507       20160507       20170507
# 1         3     0  2627626         20150507       20160507       20170507
# 2         2     0  2466007         20150506       20160506       20170506
# 3         6     1  9473473         20150506       20180506       20190506
# 4         5     1  4908816         20150506       20170506       20180506
#
#      FI_ANEXO    FF_ANEXO FI_DOCUMENTO FF_DOCUMENTO FI_VIGENCIA_ANT  \
# 0  20160507.0  20170507.0     20160507   20170507.0        20150507
# 1  20160507.0  20170507.0     20160507   20170507.0        20150507
# 2  20160506.0  20170506.0     20160506   20170506.0        20150506
# 3  20180506.0  20190506.0     20180506   20190506.0        20170506
# 4  20170506.0  20180506.0     20170506   20180506.0        20160506
#
#   FECHA_EXPE  TIPO_TRANSAC  FREC_PAGO  NRO_UNICO_TOMADOR TIPO_IDENTIFI_TOM  \
# 0   20160502             2          5             565704                 C
# 1   20160516             4          5             565704                 C
# 2   20160422             2          5             564368                 C
# 3   20180420             2          5             564368                 C
# 4   20170417             2          5             564368                 C
#
#   NRO_IDENTIFI_TOM  INTERMEDIARIO_LIDE CANAL  SEGMENTO  VR_ASEG_POLIZA  \
# 0         37514526               13336     1         1    3.042188e+09
# 1         37514526               13336     1         1    3.042188e+09
# 2         41691171               37166     1         1    3.071188e+09
# 3         41691171               37166     1         1    3.111456e+09
# 4         41691171               37166     1         1    3.072433e+09
#
#    VR_PRIMA_MN_ORIG  VR_PRIMA_PESOS  VR_PRIMA_ANUAL COD_DEPARTAMENTO  \
# 0         1146967.0       1146967.0      1146966.96               68
# 1        -1146967.0      -1146967.0      1146966.96               68
# 2          763230.0        763230.0       763229.55               11
# 3         1302616.0       1302616.0      1302617.50               11
# 4         1188728.0       1188728.0      1188729.37               11
#
#   COD_CIUDAD                   LLAVE ORIGEN         LLAVE_DT  \
# 0          1  0000857251000208002425  IAXIS  6031-100000-0-0
# 1          1  0000857251000308206344  IAXIS  6031-100000-0-0
# 2          1  0000839600000207785135  IAXIS  6031-100003-0-0
# 3          1  0000839600000623985960  IAXIS  6031-100003-0-1
# 4          1  0000839600000514516920  IAXIS  6031-100003-0-1
#
#                            LLAVE_V NRO_PLACA NRO_CHASIS  COD_MARCA  COD_CLASE  \
# 0  6031-100000-0-20160507-20170507      <NA>       <NA>       <NA>       <NA>
# 1  6031-100000-0-20160507-20170507      <NA>       <NA>       <NA>       <NA>
# 2  6031-100003-0-20160506-20170506      <NA>       <NA>       <NA>       <NA>
# 3  6031-100003-0-20180506-20190506      <NA>       <NA>       <NA>       <NA>
# 4  6031-100003-0-20170506-20180506      <NA>       <NA>       <NA>       <NA>
#
#    COD_TIPO  PESO  ANN_MODELO  CILINDRAJE  CAPACI_OCUPANTES IND_ACCESORIOS  \
# 0      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
# 1      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
# 2      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
# 3      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
# 4      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
#
#    VR_ASEG_ACCESORIOS  VR_ASEG_CASCO  TIPO_RIESGO
# 0                 NaN            NaN         <NA>
# 1                 NaN            NaN         <NA>
# 2                 NaN            NaN         <NA>
# 3                 NaN            NaN         <NA>
# 4                 NaN            NaN         <NA>

# %%
polizas_iaxis=polizas_iaxis.drop(['LLAVE'],axis=1)

# %%
polizas_iaxis=polizas_iaxis.sort_values(['LLAVE_V','LLAVE_DT'],ascending=(True,True))
# Out:
# PERIODO_CONTABLE        Int64
# SSEGURO                 Int64
# SUCURSAL_PROD          string
# RAMO_PROD              string
# POLIZA                 string
# CERTIFICADO            string
# DOCUMENTO              string
# ANEXO                  string
# RECIBO                  Int64
# FI_POLIZA_MATRIZ       string
# FI_CERTIFICADO         string
# FF_CERTIFICADO         string
# FI_ANEXO               string
# FF_ANEXO               string
# FI_DOCUMENTO           string
# FF_DOCUMENTO           string
# FI_VIGENCIA_ANT        string
# FECHA_EXPE             string
# TIPO_TRANSAC            Int64
# FREC_PAGO               Int64
# NRO_UNICO_TOMADOR       Int64
# TIPO_IDENTIFI_TOM      string
# NRO_IDENTIFI_TOM       string
# INTERMEDIARIO_LIDE      Int64
# CANAL                  string
# SEGMENTO                Int64
# VR_ASEG_POLIZA        float64
# VR_PRIMA_MN_ORIG      float64
# VR_PRIMA_PESOS        float64
# VR_PRIMA_ANUAL        float64
# COD_DEPARTAMENTO       string
# COD_CIUDAD             string
# ORIGEN                 string
# LLAVE_DT               string
# LLAVE_V                string
# NRO_PLACA              string
# NRO_CHASIS             string
# COD_MARCA               Int64
# COD_CLASE               Int64
# COD_TIPO                Int64
# PESO                    Int64
# ANN_MODELO              Int64
# CILINDRAJE              Int64
# CAPACI_OCUPANTES        Int64
# IND_ACCESORIOS         string
# VR_ASEG_ACCESORIOS    float64
# VR_ASEG_CASCO         float64
# TIPO_RIESGO             Int64
# dtype: object

# %%
# %%time
autos_as400_query = f"""SELECT DISTINCT RAMO_PROD
                              ,POLIZA
                              ,CERTIFICADO
                              ,DOCUMENTO
                              ,ANEXO
                              ,NRO_PLACA
                              ,NRO_CHASIS
                              ,COD_MARCA
                              ,COD_CLASE
                              ,COD_TIPO
                              ,PESO
                              ,ANN_MODELO
                              ,CILINDRAJE
                              ,CAPACI_OCUPANTES
                              ,IND_ACCESORIOS
                              ,VR_ASEG_ACCESORIOS
                              ,VR_ASEG_CASCO
                              /*,(ANN_CONTABLE*100+MES_CONTABLE) AS PERIODO_CONTABLE*/
                FROM DT.DWH_DT_AUT_AUTOS 
                WHERE COD_PRODUCTO IN (104,105) 
                AND ({periodo}-600)<=(ANN_CONTABLE*100+MES_CONTABLE)
                AND (ANN_CONTABLE*100+MES_CONTABLE)<= {periodo}
                AND RAMO_PROD <> 'AO'"""
autos_as400 = pd.read_sql_query(autos_as400_query,cnxn,dtype={"RAMO_PROD":"string","POLIZA":"string","CERTIFICADO":"string","DOCUMENTO":"string","ANEXO":"string","NRO_PLACA":"string","NRO_CHASIS":"string","IND_ACCESORIOS":"string","COD_MARCA":"Int64","COD_CLASE":"Int64","COD_TIPO":"Int64","PESO":"Int64","ANN_MODELO":"Int64","CILINDRAJE":"Int64","CAPACI_OCUPANTES":"Int64","VR_ASEG_ACCESORIOS":"float64","VR_ASEG_CASCO":"float64"})
# Out:
# autos_as400_query: 1.8551533182462057 min

# %%
autos_as400.RAMO_PROD=autos_as400['RAMO_PROD'].str.strip()
autos_as400.POLIZA=autos_as400['POLIZA'].str.strip()
autos_as400.CERTIFICADO=autos_as400['CERTIFICADO'].str.strip()
autos_as400.DOCUMENTO=autos_as400['DOCUMENTO'].str.strip()
autos_as400.ANEXO=autos_as400['ANEXO'].str.strip()
autos_as400.NRO_PLACA=autos_as400['NRO_PLACA'].str.strip()
autos_as400.NRO_CHASIS=autos_as400['NRO_CHASIS'].str.strip()
autos_as400.IND_ACCESORIOS=autos_as400['IND_ACCESORIOS'].str.strip()
autos_as400.NRO_PLACA=autos_as400['NRO_PLACA'].str.strip()

# %%
autos_as400['LLAVE_DT']=autos_as400['RAMO_PROD']+'-'+autos_as400['POLIZA']+'-'+autos_as400['CERTIFICADO']+'-'+autos_as400['DOCUMENTO']

# %%
autos_as400=autos_as400.sort_values(['LLAVE_DT','NRO_PLACA','DOCUMENTO'],ascending=(True,True,True))
# Out:
#        RAMO_PROD  POLIZA CERTIFICADO DOCUMENTO ANEXO NRO_PLACA  \
# 163597      6031  100000           0         2     0    RLR984
# 172174      6031  100000           0         3     0    RLR984
# 362754      6031  100003           0         2     0    CDN702
#
#                NRO_CHASIS  COD_MARCA  COD_CLASE  COD_TIPO  PESO  ANN_MODELO  \
# 163597  3GNAL7EC1BS679545         16          6       213     0        2011
# 172174  3GNAL7EC1BS679545         16          6       213     0        2011
# 362754  9FCBK456580102489         56          2       422     0        2008
#
#         CILINDRAJE  CAPACI_OCUPANTES IND_ACCESORIOS  VR_ASEG_ACCESORIOS  \
# 163597        2384                 5              S                 0.0
# 172174        2384                 5              S                 0.0
# 362754        1600                 5              S                 0.0
#
#         VR_ASEG_CASCO         LLAVE_DT
# 163597     44700000.0  6031-100000-0-2
# 172174     44700000.0  6031-100000-0-3
# 362754     22900000.0  6031-100003-0-2

# %%
autos_as400['RANK']=autos_as400.groupby('LLAVE_DT').cumcount() +1

# %%
autos_as400_count=autos_as400.groupby('LLAVE_DT').count()
autos_as400_count=autos_as400_count['RANK']
# Out:
# LLAVE_DT
# 6031-100000-0-2    1
# 6031-100000-0-3    1
# 6031-100003-0-2    1
# 6031-100003-0-4    1
# 6031-100003-0-5    1
# Name: RANK, dtype: int64

# %%
autos_as400=pd.merge(autos_as400,autos_as400_count,on=['LLAVE_DT'],how='left')
# Out:
# 3645210

# %%
autos_as400=autos_as400[autos_as400['RANK_x']==autos_as400['RANK_y']]
len(autos_as400)
# Out:
# 3637652

# %%
autos_as400=autos_as400[autos_as400.NRO_PLACA.values!='']
len(autos_as400)
# Out:
# 3613270

# %%
autos_as400['IND_ACCESORIOS']=np.where(autos_as400.IND_ACCESORIOS.values=='S','S',autos_as400['IND_ACCESORIOS'])
autos_as400['IND_ACCESORIOS']=np.where(autos_as400.IND_ACCESORIOS.values!='S','N',autos_as400['IND_ACCESORIOS'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7100917e64f2> in <module>
# ----> 1 autos_as400.loc[autos_as400["IND_ACCESORIOS"] == "S", "IND_ACCESORIOS"] = "S"
#       2 autos_as400.loc[autos_as400["IND_ACCESORIOS"] != "S", "IND_ACCESORIOS"] = "N"
#       3 autos_as400.head(3)
#
# NameError: name 'autos_as400' is not defined

# %%
autos_as400=autos_as400.drop(['RANK_x','RANK_y','RAMO_PROD','POLIZA','CERTIFICADO','ANEXO','DOCUMENTO'],axis=1)
autos_as400.head()
# Out:
#   NRO_PLACA         NRO_CHASIS  COD_MARCA  COD_CLASE  COD_TIPO  PESO  \
# 0    RLR984  3GNAL7EC1BS679545         16          6       213     0
# 1    RLR984  3GNAL7EC1BS679545         16          6       213     0
# 2    CDN702  9FCBK456580102489         56          2       422     0
# 3    UUL857  3N1CN7AD5ZK151997         64          1       218     0
# 4    UUL857  3N1CN7AD5ZK151997         64          1       218     0
#
#    ANN_MODELO  CILINDRAJE  CAPACI_OCUPANTES IND_ACCESORIOS  \
# 0        2011        2384                 5              S
# 1        2011        2384                 5              S
# 2        2008        1600                 5              S
# 3        2016        1598                 5              S
# 4        2016        1598                 5              S
#
#    VR_ASEG_ACCESORIOS  VR_ASEG_CASCO         LLAVE_DT
# 0                 0.0     44700000.0  6031-100000-0-2
# 1                 0.0     44700000.0  6031-100000-0-3
# 2                 0.0     22900000.0  6031-100003-0-2
# 3            200000.0     42100000.0  6031-100003-0-4
# 4            200000.0     42100000.0  6031-100003-0-5

# %%
#cambiar a formato COMMA20. VR_ASEG_ACCESORIOS, VR_ASEG_CASO

# %%
# %%time
polizas_as400_query = f"""SELECT PERIODO_CONTABLE 
                     ,SUCURSAL_PROD
                     ,RAMO_PROD
                     ,POLIZA
                     ,CERTIFICADO
                     ,DOCUMENTO
                     ,ANEXO
                     ,FI_POLIZA_MATRIZ
                     ,FI_CERTIFICADO
                     ,FF_CERTIFICADO
                     ,FI_ANEXO
                     ,FF_ANEXO
                     ,FI_DOCUMENTO
                     ,FF_DOCUMENTO
                     ,FI_VIGENCIA_ANT
                     ,FECHA_EXPE
                     ,TIPO_TRANSAC
                     ,FREC_PAGO
                     ,TIPO_IDENTIFI_TOM
                     ,NRO_IDENTIFI_TOM
                     ,INTERMEDIARIO_LIDE
                     ,CANAL
                     ,VR_ASEG_POLIZA
                     ,VR_PRIMA_MN_ORIG
                     ,VR_PRIMA_PESOS
                     ,VR_PRIMA_ANUAL
                     ,COD_DEPARTAMENTO
                     ,COD_CIUDAD
                     ,'AS400' AS ORIGEN
          FROM PROD.DWH_POLIZAS_H 
          WHERE ({periodo}-600)<=PERIODO_CONTABLE
          AND PERIODO_CONTABLE<= {periodo}
          /*ANNO_CONTABLE=&ANO AND MES_CONTABLE=&MES*/ 
          AND RAMO_PROD IN ('AL','AT','AU','AW','AX','CT','ET','LM','LO','ME','MO','MT','MU','MW','PE','PM','PO','TO','TP','AWL','TS','TT','TU','MF','LF'/*,'900753'*/)"""
polizas_as400_h = pd.read_sql_query(polizas_as400_query,cnxn,dtype={"PERIODO_CONTABLE":"Int64"
                                                                   ,"SUCURSAL_PROD":"string"
                                                                   ,"RAMO_PROD":"string"
                                                                   ,"POLIZA":"string"
                                                                   ,"CERTIFICADO":"string"
                                                                   ,"DOCUMENTO":"string"
                                                                   ,"ANEXO":"string"
                                                                   ,"FI_POLIZA_MATRIZ":"string"
                                                                   ,"FI_CERTIFICADO":"string"
                                                                   ,"FF_CERTIFICADO":"string"
                                                                   ,"FI_ANEXO":"string"
                                                                   ,"FF_ANEXO":"string"
                                                                   ,"FI_DOCUMENTO":"string"
                                                                   ,"FF_DOCUMENTO":"string"
                                                                   ,"FI_VIGENCIA_ANT":"string"
                                                                   ,"FECHA_EXPE":"string"
                                                                   ,"TIPO_TRANSAC":"Int64"
                                                                   ,"FREC_PAGO":"Int64"
                                                                   ,"TIPO_IDENTIFI_TOM":"string"
                                                                   ,"NRO_IDENTIFI_TOM":"string"
                                                                   ,"INTERMEDIARIO_LIDE":"Int64"
                                                                   ,"CANAL":"string"
                                                                   ,"VR_ASEG_POLIZA":"float64"
                                                                   ,"VR_PRIMA_MN_ORIG":"float64"
                                                                   ,"VR_PRIMA_PESOS":"float64"
                                                                   ,"VR_PRIMA_ANUAL":"float64"
                                                                   ,"COD_DEPARTAMENTO":"string"
                                                                   ,"COD_CIUDAD":"string"
                                                                   ,"ORIGEN":"string"})
# Out:
# polizas_as400_query: 3.2565172791481016 min

# %%
polizas_as400.RAMO_PROD=polizas_as400['RAMO_PROD'].str.strip()
polizas_as400.POLIZA=polizas_as400['POLIZA'].str.strip()
polizas_as400.DOCUMENTO=polizas_as400['DOCUMENTO'].str.strip()
polizas_as400.CERTIFICADO=polizas_as400['CERTIFICADO'].str.strip()
polizas_as400.ANEXO=polizas_as400['ANEXO'].str.strip()
polizas_as400.FI_CERTIFICADO=polizas_as400['FI_CERTIFICADO'].str.strip()
polizas_as400.FF_CERTIFICADO=polizas_as400['FF_CERTIFICADO'].str.strip()
polizas_as400.NRO_IDENTIFI_TOM=polizas_as400['NRO_IDENTIFI_TOM'].str.strip()
polizas_as400.SUCURSAL_PROD=polizas_as400['SUCURSAL_PROD'].str.strip()
polizas_as400.TIPO_IDENTIFI_TOM=polizas_as400['TIPO_IDENTIFI_TOM'].str.strip()
polizas_as400.CANAL=polizas_as400_h['CANAL'].str.strip()
polizas_as400.COD_CIUDAD=polizas_as400['COD_CIUDAD'].str.strip()
polizas_as400.COD_DEPARTAMENTO=polizas_as400['COD_DEPARTAMENTO'].str.strip()

# %%
polizas_as400.FI_CERTIFICADO=polizas_as400.FI_CERTIFICADO.str[:8]
polizas_as400.FF_CERTIFICADO=polizas_as400.FF_CERTIFICADO.str[:8]

# %%
polizas_as400['LLAVE_DT']=polizas_as400['RAMO_PROD']+'-'+polizas_as400['POLIZA'] +'-'+polizas_as400['CERTIFICADO']+'-'+polizas_as400['DOCUMENTO']
polizas_as400['LLAVE_V']=polizas_as400['RAMO_PROD']+'-'+polizas_as400['POLIZA']+'-'+polizas_as400['CERTIFICADO']+'-'+polizas_as400['FI_CERTIFICADO']+'-'+polizas_as400['FF_CERTIFICADO']

# %%
'''polizas_as400_h.FI_CERTIFICADO = pd.to_datetime(polizas_as400_h["FI_CERTIFICADO"], format= '%Y-%m-%d', errors = "coerce")
polizas_as400_h.FF_CERTIFICADO = pd.to_datetime(polizas_as400_h["FF_CERTIFICADO"], format= '%Y-%m-%d', errors = "coerce")
polizas_as400_h.FI_ANEXO = pd.to_datetime(polizas_as400_h["FI_ANEXO"], format= '%Y-%m-%d', errors = "coerce")
polizas_as400_h.FF_ANEXO = pd.to_datetime(polizas_as400_h["FF_ANEXO"], format= '%Y-%m-%d', errors = "coerce")
polizas_as400_h.FI_DOCUMENTO = pd.to_datetime(polizas_as400_h["FI_DOCUMENTO"], format= '%Y-%m-%d', errors = "coerce")
polizas_as400_h.FF_DOCUMENTO = pd.to_datetime(polizas_as400_h["FF_DOCUMENTO"], format= '%Y-%m-%d', errors = "coerce")
polizas_as400_h.FI_POLIZA_MATRIZ = pd.to_datetime(polizas_as400_h["FI_POLIZA_MATRIZ"], format= '%Y-%m-%d', errors = "coerce")
polizas_as400_h.FI_VIGENCIA_ANT = pd.to_datetime(polizas_as400_h["FI_VIGENCIA_ANT"], format= '%Y-%m-%d', errors = "coerce")
polizas_as400_h.FECHA_EXPE = pd.to_datetime(polizas_as400_h["FECHA_EXPE"], format= '%Y-%m-%d', errors = "coerce")
polizas_as400_h.dtypes'''

# %%
polizas_as400=pd.merge(polizas_as400,autos_as400,on=['LLAVE_DT'],how='left')
# Out:
#    PERIODO_CONTABLE SUCURSAL_PROD RAMO_PROD POLIZA CERTIFICADO DOCUMENTO  \
# 0            201602             2        AW   7196         106       805
# 1            201602             2        AW   7196         114       805
# 2            201602             2        AW   7196         118       405
# 3            201602             2        AW   7196         119       405
# 4            201602             2        AW   7196         120       605
#
#   ANEXO FI_POLIZA_MATRIZ FI_CERTIFICADO FF_CERTIFICADO  FI_ANEXO  FF_ANEXO  \
# 0     8         20090715       20150901       20160901  20160201  20160201
# 1     8         20120101       20150901       20160901  20160201  20160201
# 2     4         20120101       20150901       20160901  20160201  20160201
# 3     4         20120101       20150901       20160901  20160201  20160201
# 4     6         20120101       20150901       20160901  20160201  20160201
#
#   FI_DOCUMENTO FF_DOCUMENTO FI_VIGENCIA_ANT FECHA_EXPE  TIPO_TRANSAC  \
# 0     20160101     20160201        20140901   20160201             9
# 1     20160101     20160201        20140901   20160201             9
# 2     20160101     20160201        20140901   20160201             9
# 3     20160101     20160201        20140901   20160201             9
# 4     20160101     20160201        20140901   20160201             9
#
#    FREC_PAGO TIPO_IDENTIFI_TOM NRO_IDENTIFI_TOM  INTERMEDIARIO_LIDE CANAL  \
# 0          1                 N        800037133               10048     A
# 1          1                 N        800037133               10048     A
# 2          1                 N        800037133               10048     A
# 3          1                 N        800037133               10048     A
# 4          1                 N        800037133               10048     A
#
#    VR_ASEG_POLIZA  VR_PRIMA_MN_ORIG  VR_PRIMA_PESOS  VR_PRIMA_ANUAL  \
# 0    3.031216e+09           64929.0         64929.0        779140.0
# 1    3.057121e+09           85917.0         85917.0       1030997.0
# 2    3.023821e+09           53049.0         53049.0        636581.0
# 3    3.028821e+09           52665.0         52665.0        631972.0
# 4    3.029721e+09           62160.0         62160.0        745911.0
#
#   COD_DEPARTAMENTO COD_CIUDAD ORIGEN         LLAVE_DT  \
# 0               11          1  AS400  AW-7196-106-805
# 1               11          1  AS400  AW-7196-114-805
# 2               11          1  AS400  AW-7196-118-405
# 3               11          1  AS400  AW-7196-119-405
# 4               11          1  AS400  AW-7196-120-605
#
#                          LLAVE_V NRO_PLACA NRO_CHASIS  COD_MARCA  COD_CLASE  \
# 0  AW-7196-106-20150901-20160901      <NA>       <NA>       <NA>       <NA>
# 1  AW-7196-114-20150901-20160901      <NA>       <NA>       <NA>       <NA>
# 2  AW-7196-118-20150901-20160901      <NA>       <NA>       <NA>       <NA>
# 3  AW-7196-119-20150901-20160901      <NA>       <NA>       <NA>       <NA>
# 4  AW-7196-120-20150901-20160901      <NA>       <NA>       <NA>       <NA>
#
#    COD_TIPO  PESO  ANN_MODELO  CILINDRAJE  CAPACI_OCUPANTES IND_ACCESORIOS  \
# 0      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
# 1      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
# 2      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
# 3      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
# 4      <NA>  <NA>        <NA>        <NA>              <NA>           <NA>
#
#    VR_ASEG_ACCESORIOS  VR_ASEG_CASCO
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN

# %%
base_pp_mes=pd.concat([polizas_iaxis,polizas_as400],ignore_index=True)
base_pp_mes.dtypes
# Out:
# PERIODO_CONTABLE        Int64
# SSEGURO                 Int64
# SUCURSAL_PROD          string
# RAMO_PROD              string
# POLIZA                 string
# CERTIFICADO            string
# DOCUMENTO              string
# ANEXO                  string
# RECIBO                  Int64
# FI_POLIZA_MATRIZ       string
# FI_CERTIFICADO         string
# FF_CERTIFICADO         string
# FI_ANEXO               string
# FF_ANEXO               string
# FI_DOCUMENTO           string
# FF_DOCUMENTO           string
# FI_VIGENCIA_ANT        string
# FECHA_EXPE             string
# TIPO_TRANSAC            Int64
# FREC_PAGO               Int64
# NRO_UNICO_TOMADOR       Int64
# TIPO_IDENTIFI_TOM      string
# NRO_IDENTIFI_TOM       string
# INTERMEDIARIO_LIDE      Int64
# CANAL                  string
# SEGMENTO                Int64
# VR_ASEG_POLIZA        float64
# VR_PRIMA_MN_ORIG      float64
# VR_PRIMA_PESOS        float64
# VR_PRIMA_ANUAL        float64
# COD_DEPARTAMENTO       string
# COD_CIUDAD             string
# ORIGEN                 string
# LLAVE_DT               string
# LLAVE_V                string
# NRO_PLACA              string
# NRO_CHASIS             string
# COD_MARCA               Int64
# COD_CLASE               Int64
# COD_TIPO                Int64
# PESO                    Int64
# ANN_MODELO              Int64
# CILINDRAJE              Int64
# CAPACI_OCUPANTES        Int64
# IND_ACCESORIOS         string
# VR_ASEG_ACCESORIOS    float64
# VR_ASEG_CASCO         float64
# TIPO_RIESGO             Int64
# dtype: object

# %%
# %%time
intermediarios_query=f'''SELECT DISTINCT COD_INTERMEDIARIO AS INTERMEDIARIO_LIDE
                                        ,COD_SUCURSAL AS SUCURSAL_PROD
                         FROM APOYO.DWH_INTERMEDIARIOS_TOTAL'''

intermediarios = pd.read_sql_query(intermediarios_query,cnxn,dtype={'INTERMEDIARIO_LIDE':'Int32','SUCURSAL_PROD':'Int32'})
# Out:
# intermediarios_query: 0.002581357955932617 min

# %%
base_pp_mes=pd.merge(base_pp_mes,intermediarios,on=['INTERMEDIARIO_LIDE'],how='left')
base_pp_mes.dtypes
# Out:
# PERIODO_CONTABLE        Int64
# SSEGURO                 Int64
# SUCURSAL_PROD_x        string
# RAMO_PROD              string
# POLIZA                 string
# CERTIFICADO            string
# DOCUMENTO              string
# ANEXO                  string
# RECIBO                  Int64
# FI_POLIZA_MATRIZ       string
# FI_CERTIFICADO         string
# FF_CERTIFICADO         string
# FI_ANEXO               string
# FF_ANEXO               string
# FI_DOCUMENTO           string
# FF_DOCUMENTO           string
# FI_VIGENCIA_ANT        string
# FECHA_EXPE             string
# TIPO_TRANSAC            Int64
# FREC_PAGO               Int64
# NRO_UNICO_TOMADOR       Int64
# TIPO_IDENTIFI_TOM      string
# NRO_IDENTIFI_TOM       string
# INTERMEDIARIO_LIDE      Int64
# CANAL                  string
# SEGMENTO                Int64
# VR_ASEG_POLIZA        float64
# VR_PRIMA_MN_ORIG      float64
# VR_PRIMA_PESOS        float64
# VR_PRIMA_ANUAL        float64
# COD_DEPARTAMENTO       string
# COD_CIUDAD             string
# ORIGEN                 string
# LLAVE_DT               string
# LLAVE_V                string
# NRO_PLACA              string
# NRO_CHASIS             string
# COD_MARCA               Int64
# COD_CLASE               Int64
# COD_TIPO                Int64
# PESO                    Int64
# ANN_MODELO              Int64
# CILINDRAJE              Int64
# CAPACI_OCUPANTES        Int64
# IND_ACCESORIOS         string
# VR_ASEG_ACCESORIOS    float64
# VR_ASEG_CASCO         float64
# TIPO_RIESGO             Int64
# SUCURSAL_PROD_y         Int64
# dtype: object

# %%
#cual sucursal va primero?
base_pp_mes['SUCURSAL_PROD']=(base_pp_mes['SUCURSAL_PROD_y'].combine_first(base_pp_mes['SUCURSAL_PROD_x']))
base_pp_mes.head()
# Out:
#    PERIODO_CONTABLE  SSEGURO SUCURSAL_PROD_x RAMO_PROD  POLIZA CERTIFICADO  \
# 0            201605   857251              13      6031  100000           0
# 1            201605   857251              13      6031  100000           0
# 2            201605   839600              37      6031  100003           0
# 3            201701   839600              37      6031  100003           0
# 4            201705   839600              37      6031  100003           0
#
#   DOCUMENTO ANEXO   RECIBO FI_POLIZA_MATRIZ FI_CERTIFICADO FF_CERTIFICADO  \
# 0         2     0  2554383         20150507       20160507       20170507
# 1         3     0  2627626         20150507       20160507       20170507
# 2         2     0  2466007         20150506       20160506       20170506
# 3         4     1  4180114         20150506       20160506       20170506
# 4         5     1  4908816         20150506       20170506       20180506
#
#      FI_ANEXO    FF_ANEXO FI_DOCUMENTO FF_DOCUMENTO FI_VIGENCIA_ANT  \
# 0  20160507.0  20170507.0     20160507   20170507.0        20150507
# 1  20160507.0  20170507.0     20160507   20170507.0        20150507
# 2  20160506.0  20170506.0     20160506   20170506.0        20150506
# 3  20170107.0  20170506.0     20170107   20170506.0        20150506
# 4  20170506.0  20180506.0     20170506   20180506.0        20160506
#
#   FECHA_EXPE  TIPO_TRANSAC  FREC_PAGO  NRO_UNICO_TOMADOR TIPO_IDENTIFI_TOM  \
# 0   20160502             2          5             565704                 C
# 1   20160516             4          5             565704                 C
# 2   20160422             2          5             564368                 C
# 3   20170111             8          5             564368                 C
# 4   20170417             2          5             564368                 C
#
#   NRO_IDENTIFI_TOM  INTERMEDIARIO_LIDE CANAL  SEGMENTO  VR_ASEG_POLIZA  \
# 0         37514526               13336     1         1    3.042188e+09
# 1         37514526               13336     1         1    3.042188e+09
# 2         41691171               37166     1         1    3.071188e+09
# 3         41691171               37166     1         1    3.071188e+09
# 4         41691171               37166     1         1    3.072433e+09
#
#    VR_PRIMA_MN_ORIG  VR_PRIMA_PESOS  VR_PRIMA_ANUAL COD_DEPARTAMENTO  \
# 0         1146967.0       1146967.0      1146966.96               68
# 1        -1146967.0      -1146967.0      1146966.96               68
# 2          763230.0        763230.0       763229.55               11
# 3          109390.0        109390.0       771788.00               11
# 4         1188728.0       1188728.0      1188729.37               11
#
#   COD_CIUDAD ORIGEN         LLAVE_DT                          LLAVE_V  \
# 0          1  IAXIS  6031-100000-0-0  6031-100000-0-20160507-20170507
# 1          1  IAXIS  6031-100000-0-0  6031-100000-0-20160507-20170507
# 2          1  IAXIS  6031-100003-0-0  6031-100003-0-20160506-20170506
# 3          1  IAXIS  6031-100003-0-1  6031-100003-0-20160506-20170506
# 4          1  IAXIS  6031-100003-0-1  6031-100003-0-20170506-20180506
#
#   NRO_PLACA NRO_CHASIS  COD_MARCA  COD_CLASE  COD_TIPO  PESO  ANN_MODELO  \
# 0      <NA>       <NA>       <NA>       <NA>      <NA>  <NA>        <NA>
# 1      <NA>       <NA>       <NA>       <NA>      <NA>  <NA>        <NA>
# 2      <NA>       <NA>       <NA>       <NA>      <NA>  <NA>        <NA>
# 3      <NA>       <NA>       <NA>       <NA>      <NA>  <NA>        <NA>
# 4      <NA>       <NA>       <NA>       <NA>      <NA>  <NA>        <NA>
#
#    CILINDRAJE  CAPACI_OCUPANTES IND_ACCESORIOS  VR_ASEG_ACCESORIOS  \
# 0        <NA>              <NA>           <NA>                 NaN
# 1        <NA>              <NA>           <NA>                 NaN
# 2        <NA>              <NA>           <NA>                 NaN
# 3        <NA>              <NA>           <NA>                 NaN
# 4        <NA>              <NA>           <NA>                 NaN
#
#    VR_ASEG_CASCO  TIPO_RIESGO  SUCURSAL_PROD_y  SUCURSAL_PROD
# 0            NaN         <NA>               13             13
# 1            NaN         <NA>               13             13
# 2            NaN         <NA>              221            221
# 3            NaN         <NA>              221            221
# 4            NaN         <NA>              221            221

# %%
base_pp_mes=base_pp_mes.drop(['SUCURSAL_PROD_x','SUCURSAL_PROD_y'],axis=1)
base_pp_mes.dtypes
# Out:
# PERIODO_CONTABLE        Int64
# SSEGURO                 Int64
# RAMO_PROD              string
# POLIZA                 string
# CERTIFICADO            string
# DOCUMENTO              string
# ANEXO                  string
# RECIBO                  Int64
# FI_POLIZA_MATRIZ       string
# FI_CERTIFICADO         string
# FF_CERTIFICADO         string
# FI_ANEXO               string
# FF_ANEXO               string
# FI_DOCUMENTO           string
# FF_DOCUMENTO           string
# FI_VIGENCIA_ANT        string
# FECHA_EXPE             string
# TIPO_TRANSAC            Int64
# FREC_PAGO               Int64
# NRO_UNICO_TOMADOR       Int64
# TIPO_IDENTIFI_TOM      string
# NRO_IDENTIFI_TOM       string
# INTERMEDIARIO_LIDE      Int64
# CANAL                  string
# SEGMENTO                Int64
# VR_ASEG_POLIZA        float64
# VR_PRIMA_MN_ORIG      float64
# VR_PRIMA_PESOS        float64
# VR_PRIMA_ANUAL        float64
# COD_DEPARTAMENTO       string
# COD_CIUDAD             string
# ORIGEN                 string
# LLAVE_DT               string
# LLAVE_V                string
# NRO_PLACA              string
# NRO_CHASIS             string
# COD_MARCA               Int64
# COD_CLASE               Int64
# COD_TIPO                Int64
# PESO                    Int64
# ANN_MODELO              Int64
# CILINDRAJE              Int64
# CAPACI_OCUPANTES        Int64
# IND_ACCESORIOS         string
# VR_ASEG_ACCESORIOS    float64
# VR_ASEG_CASCO         float64
# TIPO_RIESGO             Int64
# SUCURSAL_PROD           Int64
# dtype: object

# %%
#base_pp_mes.to_csv("base_pp_mes.csv")

# %%
#BASE_PP_MOD_2 -> CONCATENACION HISTORICO (6 AÑOS) + PERIODO
#base_pp_mes.to_csv("base_pp_mod_2.csv")

# %%
#CONVERT TO DATE 
base_pp_mes['DIF']=np.where(base_pp_mes['ORIGEN']=='AS400',base_pp_mes['FF_DOCUMENTO']-base_pp_mes['FI_DOCUMENTO'],base_pp_mes['FF_ANEXO']-base_pp_mes['FI_ANEXO'])
base_pp_mes['DIF']=base_pp_mes.DIF.dt.days
base_pp_mes.head()

# %%
'''base_1.DIF = base_1.DIF.astype('string')
base_1.DIF = base_1.DIF.replace(' days','', regex=True)
base_1.DIF = base_1.DIF.astype('Int64')
base_1.dtypes'''

# %%
tipo_transac=[28,29,30,31]
base_pp_mes['TIPO_TRANSAC']=np.where(((base_pp_mes.TIPO_TRANSAC.values==8)&(base_pp_mes.VR_PRIMA_MN_ORIG.values>0)&(pd.DataFrame(base_pp_mes.TIPO_TRANSAC.tolist()).isin(tipo_transac).any(axis=1).values)),9,base_pp_mes['TIPO_TRANSAC'])
base_pp_mes['TIPO_TRANSAC']=np.where(((base_pp_mes.TIPO_TRANSAC.values==8)&(base_pp_mes.VR_PRIMA_MN_ORIG.values<0)&(pd.DataFrame(base_pp_mes.TIPO_TRANSAC.tolist()).isin(tipo_transac).any(axis=1).values)),8,base_pp_mes['TIPO_TRANSAC'])

# %%
'''base_1.FI_DOCUMENTO = pd.to_datetime(base_1["FI_DOCUMENTO"], format= '%Y-%m-%d',errors = "coerce")
base_1.FF_DOCUMENTO = pd.to_datetime(base_1["FF_DOCUMENTO"], format= '%Y-%m-%d',errors = "coerce")
base_1.FF_ANEXO = pd.to_datetime(base_1["FF_ANEXO"], format= '%Y-%m-%d',errors = "coerce")
base_1.FI_ANEXO = pd.to_datetime(base_1["FI_ANEXO"], format= '%Y-%m-%d',errors = "coerce")
base_1.FI_CERTIFICADO = pd.to_datetime(base_1["FI_CERTIFICADO"], format= '%Y-%m-%d',errors = "coerce")
base_1.FF_CERTIFICADO = pd.to_datetime(base_1["FF_CERTIFICADO"], format= '%Y-%m-%d',errors = "coerce")
base_1.FI_POLIZA_MATRIZ = pd.to_datetime(base_1["FI_POLIZA_MATRIZ"], format= '%Y-%m-%d',errors = "coerce")
base_1.FI_VIGENCIA_ANT = pd.to_datetime(base_1["FI_VIGENCIA_ANT"], format= '%Y-%m-%d',errors = "coerce")
base_1.FECHA_EXPE = pd.to_datetime(base_1["FECHA_EXPE"], format= '%Y-%m-%d',errors = "coerce")
base_1.head()'''

# %%
autos=base_pp_mes.loc[:,["LLAVE_DT","NRO_PLACA","NRO_CHASIS","COD_MARCA","COD_CLASE","COD_TIPO","PESO","ANN_MODELO","CILINDRAJE","CAPACI_OCUPANTES","IND_ACCESORIOS","VR_ASEG_ACCESORIOS","VR_ASEG_CASCO"]].copy()
autos=autos.drop_duplicates()
autos.head()

# %%
imagen=base_pp_mes.groupby("LLAVE_V").agg({"ANEXO":'max',"DOCUMENTO":'max'})
imagen.rename(columns = {"ANEXO":"ANEXO_MAX","DOCUMENTO":"DOCUMENTO_MAX"}, inplace = True)
imagen.head()

# %%
base_pp_mes=pd.merge(base_pp_mes,imagen,on=['LLAVE_V'],how='left')
base_pp_mes.dtypes

# %%
base_pp_mes=base_pp_mes[["PERIODO_CONTABLE","SSEGURO","SUCURSAL_PROD","RAMO_PROD","POLIZA","CERTIFICADO","DOCUMENTO","ANEXO","RECIBO""","FI_POLIZA_MATRIZ","FI_CERTIFICADO","FF_CERTIFICADO","FI_ANEXO","FF_ANEXO","FI_DOCUMENTO","FF_DOCUMENTO","FI_VIGENCIA_ANT","FECHA_EXPE","TIPO_TRANSAC","FREC_PAGO","NRO_UNICO_TOMADOR","TIPO_IDENTIFI_TOM","NRO_IDENTIFI_TOM","INTERMEDIARIO_LIDE","CANAL","SEGMENTO","VR_ASEG_POLIZA","VR_PRIMA_MN_ORIG","VR_PRIMA_PESOS","VR_PRIMA_ANUAL","COD_DEPARTAMENTO","COD_CIUDAD","LLAVE_DT","LLAVE_V","ORIGEN","TIPO_RIESGO"]]
base_pp_mes['IMAGEN']=np.where(base_pp_mes['ORIGEN']=='AS400','D','A')
base_pp_mes['LLAVE_DT_M']=base_pp_mes['RAMO_PROD']+'-'+base_1["POLIZA"] + "-" + base_1["CERTIFICADO"] + "-" + base_1["IMAGEN"]

# %%
base_1 = pd.merge(base_1,autos,on=["LLAVE_DT"],how="left")
len(base_1)

# %%
#REVISAR NRO_PLACA, es igual a LLENOS?
llenos_1 = base_1.loc[base_1["NRO_PLACA"] != '',:].copy()

# %%
vacios_1 = base_1.loc[vacios_1["NRO_PLACA"].isna(),:].copy()

# %%
vacios_2 = vacios_1.loc[:,["RAMO_PROD","POLIZA","CERTIFICADO","FI_CERTIFICADO","FF_CERTIFICADO","LLAVE_V"]].copy()

# %%
llenos = base_1.loc[base_2["NRO_PLACA"].notnull(),["RAMO_PROD","POLIZA","CERTIFICADO","FI_CERTIFICADO","FF_CERTIFICADO","LLAVE_V","NRO_PLACA","NRO_CHASIS","COD_MARCA","COD_CLASE","COD_TIPO","PESO","ANN_MODELO","CILINDRAJE","CAPACI_OCUPANTES","IND_ACCESORIOS","VR_ASEG_ACCESORIOS","VR_ASEG_CASCO"]].copy()
llenos = llenos.drop_duplicates()
llenos.rename(columns = {"FI_CERTIFICADO":"FI","FF_CERTIFICADO":"FF"}, inplace = True)

# %%
a_llenar_1 = pd.merge(vacios_2,llenos,on=["RAMO_PROD","POLIZA","CERTIFICADO"],how="left")
a_llenar_1.head()

# %%
a_llenar_1["LLAVE_V"] = (a_llenar_1["LLAVE_V_x"].combine_first(a_llenar_1["LLAVE_V_y"]))
a_llenar_1 = a_llenar_1.drop(["LLAVE_V_x","LLAVE_V_y"],axis = 1)
a_llenar_1.head()

# %%
a_llenar_1.FI_CERTIFICADO = pd.to_datetime(a_llenar_1["FI_CERTIFICADO"], format= '%Y-%m-%d',errors = "coerce")
a_llenar_1.FI = pd.to_datetime(a_llenar_1["FI"], format= '%Y-%m-%d',errors = "coerce")
a_llenar_1.head()

# %%
a_llenar_1["DIF"] = a_llenar_1["FI_CERTIFICADO"] - a_llenar_1["FI"]
a_llenar_1 = a_llenar_1[a_llenar_1["NRO_PLACA"].notnull()]
a_llenar_1.drop_duplicates()
a_llenar_1.sort_values(["LLAVE_V","DIF"],ascending = (True,True))
a_llenar_1["RANK"] = a_llenar_1.groupby("LLAVE_V").cumcount() +1
a_llenar_1 = a_llenar_1[a_llenar_1["RANK"] == 1]
a_llenar_1 = a_llenar_1.drop(["RANK","DIF","FI","FF"],axis = 1)
a_llenar_1.dtypes
a_llenar_1.head()

# %%
#SERVIRA GENERAR UN VACIOS_3
vacios_3 = pd.merge(vacios_1,a_llenar,on=["LLAVE_V"],how="left")
vacios_3.dtypes

# %%
base_3_1 = pd.concat([llenos_1,vacios_3],ignore_index=True)
base_3_1.head()

# %%
def ot(x):
    if ((x["TIPO_TRANSAC"] == 1)):
        return "A"
    elif ((x["TIPO_TRANSAC"] == 2)):
        return "B"
    elif ((x["TIPO_TRANSAC"] == 9)):
        return "C"
    elif ((x["TIPO_TRANSAC"] == 5)):
        return "D"
    elif ((x["TIPO_TRANSAC"] == 7)):
        return "E" 
    elif ((x["TIPO_TRANSAC"] == 8)):
        return "F" 
    elif ((x["TIPO_TRANSAC"] == 4)):
        return "G" 
    elif ((x["TIPO_TRANSAC"] == 12)):
        return "H"
    else:
        "I"
         
    

base_3_1["OT"] = base_3_1.apply(ot, axis=1)
base_3_1["PLACA_VIG"] = base_3_1["NRO_PLACA"] + "-" + base_3_1["FI_CERTIFICADO"] + "-" + base_3_1["FF_CERTIFICADO"]

# %%
base_3_1 = base_3_1.sort_values(["PLACA_VIG","RAMO_PROD","POLIZA","CERTIFICADO","OT","PERIODO_CONTABLE"],ascending=(True,True,True,True,True,True))

# %%
base_3_1["RANK"] = base_3_1.groupby("LLAVE_V").cumcount() +1
base_3_1 = base_3_1.drop([(base_3_1.TIPO_TRANSAC in < (7,8,9)) & (base_3_1.NUEVO_DOCUMENTO > 1)].index)
base_3_1["PN"] = np.where(base_3_1["TIPO_TRANSAC"] in (4,12),"N","P")

# %%
base_3_1["N"] = np.where(base_3_1["PN"] == "N",1,0)
base_3_1["P"] = np.where(base_3_1["PN"] == "P",1,0)

# %%
base_3_1["LLAVE_5"] = base_3_1["NRO_PLACA"] +"-"+ base_3_1["FI_CERTIFICADO"] +"-"+ base_3_1["FF_CERTIFICADO"] +"-"+ base_3_1["PN"]

# %%
base_3_1 = base_3_1[base_3_1["TIPO_TRANSAC"] != ' ']

# %%
cuenta = base_4_1.groupby("PLACA_VIG").agg({"P":'sum',"N":'max'})
cuenta.rename(columns = {"P":"POSITIVA","N":"NEGATIVA"}, inplace = True)

# %%
base_3_1 = pd.merge(base_3_1,cuenta,on=["PLACA_VIG"],how="left")

# %%
base_3_1 = pd.merge(base_3_1,aseg_dt,on=["LLAVE_DT"],how="left")

# %%
base_3_1 = base_3_1.sort_values(["LLAVE_5","RAMO_PROD","POLIZA","CERTIFICADO","PERIODO_CONTABLE","OT"],ascending = (True,True,True,True,True,True))

# %%
base_4 = base_4_2
base_4["RANK"] = base_4.groupby("LLAVE_5").cumcount() +1
base_4["DIF"] = np.where(base_4["RANK"] == 1, base_4["POSITIVA"] - base_4["NEGATIVA"],base_4["DIF"])
base_4 = base_4.drop([(base_4.DIF >0 ) & (base_4.PN == "N")].index)
base_4 = base_4.drop([(base_4.NRO_PLACA.isna() ) & (base_4.NRO_IDENTIFI_ASEG.isna())].index)
base_4 = base_4.drop(["POSITIVA","NEGATIVA","LLAVE_5","DIF"], axis = 1)

# %%
base_4.sort_values(["ORIGEN","PLACA_VIG","PN","RAMO_PROD","POLIZA","CERTIFICADO","PERIODO_CONTABLE","RECIBO","OT"],ascending = (True,True,False,False,False,False,False,False,False))

# %%
base_5_1 = base_5_1[base_5_1["RAMO_PROD"] in ('6031','6032','6033','6034','6035','6036','6037','6043','6048','6060','6061','AL','AU','AX','CT','PM','LM','MT','MU','ME','MW') & base_5_1["SUCURSAL_PROD"].isin([177,214])]
base_5_1["LLAVE_RIESGO"] = base_5_1["NRO_PLACA"] +"-"+ base_5_1["TIPO_IDENTIFI_ASEG"] +"-"+ base_5_1["NRO_IDENTIFI_ASEG"] 
base_5_1 = base_5_1[base_5_1["NRO_PLACA"] != "ZZZZ1"]

# %%
dicc = {"ZONA":"string","SUCURSAL":"Int64"}

zonas_act = pd.read_csv("zonas_act.csv", sep = ';' , dtype = dicc)
zonas_act.reset_index(drop=True, inplace=True)
zonas_act.rename(columns = {"SUCURSAL":"SUCURSAL_PROD"}, inplace = True)
zonas_act.head()

# %%
base_5_2 = pd.merge(base_5_1,zonas_act,on=["SUCURSAL_PROD"],how="left")
base_5_2.sort_values(["LLAVE_RIESGO","FI_CERTIFICADO","PN","RAMO_PROD","POLIZA","CERTIFICADO","FECHA_EXPE","RECIBO","ANEXO","OT"],ascending=(True,True,True,False,False,False,False,False,False,False,False))

# %%
base_r = base_5_2
#lenght indicador marca_nr $20.
base_r = base_r.drop(["NUEVO_DOCUMENTO"], axis = 1)
base_r["ND"] = base_r.groupby("LLAVE_RIESGO").cumcount() +1
base_r["ANTERIOR"] = base_r["ND"] - 1

# %%
def marca_nr(x):
    if ((x["ND"] == 1) & (x["PN"] == "P")):
        return "NUEVA"
    elif ((x["ND"] == 1) & (x["PN"] == "N")):
        return "NUEVA_CANCELADA"
     
base_r["MARCA_NR"] = base_r.apply(marca_nr, axis=1)

# %%
sucursal_prod_not_list = [177,214]
ramo_prod_privado = ['6031','6032','6033','6034','6035','6036','6037','6043','6048','6060','6061','AL','AU','AX','CT','PM','LM','MT','MU','ME','MW']
ramo_prod_colectivo = ['AT','AW','PE','TP','TT','TS','TU','6041','6042','6045','6046','6047','6038','6039','LO','MO','PO','TO','LF','MF','900753']
not_ramo_prod_list = ['AT','AW','PE','TT','TS','6041','6042','6045','6046','6047','LO','MO','PO','TO','LF','MF','900753']
ramo_prod_banco = ['LO','MO','PO','TO','LF','MF','900753']

base_privado = base_4.loc[(~base_4.SUCURSAL_PROD.isin(sucursal_prod_not_list))&(pd.DataFrame(base_4.RAMO_PROD.tolist()).isin(ramo_prod_privado).any(axis=1).values)&(base_4.NRO_PLACA.values!='ZZZZ1'),:].copy()
base_privado = pd.merge(base_privado,zonas_act,on='',how='')
base_privado = base_privado.sort_values(['',''],ascending=)

base_colectivo = base_4.loc[(~base_4.SUCURSAL_PROD.isin(sucursal_prod_not_list))&(pd.DataFrame(base_4.RAMO_PROD.tolist()).isin(ramo_prod_colectivo).any(axis=1).values)&(base_4.NRO_PLACA.values!='ZZZZ1'),:].copy()
base_colectivo = base_colectivo.drop(base_colectivo[(pd.DataFrame(df.RAMO_PROD.tolist()).isin(not_ramo_prod_list).any(axis=1).values)&(base_colectivo.DOCUMENTO.values=='0')].index)
base_colectivo = pd.merge(base_colectivo,zonas_act,on='',how='')
base_colectivo = base_colectivo.sort_values(['',''],ascending=)

base_banco = base_4.loc[(base_4.SUCURSAL_PROD.values==214)&(pd.DataFrame(base_4.RAMO_PROD.tolist()).isin(ramo_prod_banco).any(axis=1).values)&(base_4.NRO_PLACA.values!='ZZZZ1'),:].copy()
base_banco = base_banco.drop(base_colectivo[(base_colectivo.TIPO_TRANSAC.values==7)&(base_colectivo.VR_PRIMA_ANUAL.values=='0')].index)
base_banco = pd.merge(base_banco,caratula_banco,on='',how='')
base_banco = base_banco.sort_values(['',''],ascending=)

base_coomeva = base_4.loc[(base_4.SUCURSAL_PROD.values==177)&(base_4.NRO_PLACA.values!='ZZZZ1'),:].copy()
base_coomeva = pd.merge(base_coomeva,zona_coomeva,on='',how='')
base_coomeva = base_coomeva.sort_values(['',''],ascending=)

#list_of_df = [base_privado,base_colectivo,base_banco,base_coomeva]

# %%
#CICLO
bases = [base_privado,base_colectivo,base_banco,base_coomeva]
errores_bases = []
for base in bases:
    counter = 0
    
    base['ND'] = base.groupby('LLAVE_RIESGO').cumcount()+1
    base['ANTERIOR']=base['ND']-1
    base['MARCA_NR']=''
    base['MARCA_NR']=np.where((base.ND.values==1)&(base.PN.values=='P'),'NUEVA',base['MARCA_NR'])
    base['MARCA_NR']=np.where((base.ND.values==1)&(base.PN.values=='N'),'NUEVA_CANCELADA',base['MARCA_NR'])
    base['INDICADOR']=''
    base['M']=''
    while (len(base[base['MARCA_NR']==''])>0):
        counter += 1
        #ITERACION
        anterior = base.loc[base.ND.values==counter,['LLAVE_RIESGO','ND','FI_CERTIFICADO','FF_CERTIFICADO','MARCA_NR']].copy()
        anterior.rename(columns={'LLAVE_RIESGO':'LLR','FI_CERTIFICADO':'FI_1','FF_CERTIFICADO':'FF_1','MARCA_NR':'MARCA_1','ND':'ND_ANTERIOR'},inplace=True)

        base = pd.merge(base,anterior,left_on=['LLAVE_RIESGO','ANTERIOR'],right_on=['LLR','ND_ANTERIOR'],how='left')
        #regla1
        list_1=['NUEVA','NUEVA_CANCELADA']
        base['INDICADOR']=np.where((pd.DataFrame(base.MARCA_1.tolist()).isin(list_1).any(axis=1).values)&(base.PN.values=='N'),'NUEVA_CANCELADA',base['INDICADOR'])
        #regla2
        list_2=['RENOVADA','RENOVADA_CANCELADA']
        base['INDICADOR']=np.where((pd.DataFrame(base.MARCA_1.tolist()).isin(list_2).any(axis=1).values)&(base.PN.values=='N')&(base.INDICADOR.values=='')&(base.FI_CERTIFICADO.values==base.FI_1.values),'RENOVADA_CANCELADA',base['INDICADOR'])
        #regla3
        base['INDICADOR']=np.where((base.PN.values=='P')&(base.INDICADOR.values=='')&(base.FI_CERTIFICADO.values>=base.FF_1.values),'RENOVADA',base['INDICADOR'])
        #regla4
        base['INDICADOR']=np.where((base.PN.values=='P')&(base.INDICADOR.values=='')&(base.FI_CERTIFICADO.values>=base.FI_1.values)&(base.MARCA_1=='RENOVADA_CANCELADA'),'RENOVADA',base['INDICADOR'])
        #regla5
        base['INDICADOR']=np.where((base.PN.values=='P')&(base.INDICADOR.values=='')&(base.FI_CERTIFICADO.values<base.FF_1.values),'NUEVA',base['INDICADOR'])
        #regla6
        base['INDICADOR']=np.where((base.PN.values=='P')&(base.INDICADOR.values=='')&(base.FI_CERTIFICADO.values>base.FF_1.values),'NUEVA',base['INDICADOR'])
        #regla7
        base['INDICADOR']=np.where((base.PN.values=='N')&(base.INDICADOR.values=='')&(base.FI_CERTIFICADO.values!=base.FI_1.values)&(pd.DataFrame(base.MARCA_1.tolist()).isin(list_2).any(axis=1).values),'NUEVA_CANCELADA',base['INDICADOR'])
        #regla8
        base['MARCA_NR']=np.where((base.INDICADOR.values!='')&(base.ND.values==counter+1)&(base.MARCA_NR.values==''),base['INDICADOR'],base['MARCA_NR'])
        #regla9
        base['M']=np.where((base.ND.values==counter+1)&(base.MARCA_NR.values==''),1,base['M'])
        #regla10
        base['INDICADOR']=np.where((base.ND.values>counter+1),'',base['INDICADOR'])
        
        errores = base.loc[base.M.values==1,['FI_CERTIFICADO','FF_CERTIFICADO','FI_1','FF_1']].copy()
        errores.rename(columns={'FI_CERTIFICADO':'FI','FF_CERTIFICADO':'FF'},inplace=True)
        errores['DIF_I'] = ((errores['FI']-errores['FI_1']).dt.days)/365
        errores['DIF_F'] = ((errores['FF']-errores['FF_1']).dt.days)/365
        
        base = base.drop(['LLR','ND_ANTERIOR','FI_1','FF_1','MARCA_1'], axis = 1)
        
    #¡aplico append aca abajo o afuera del for?
    errores_base.append(errores)
    marca_f = base.loc[:,['LLAVE_RIESGO','ANTERIOR','MARCA_NR']].copy()
    marca_f.rename(columns = {'MARCA_NR':'MARCA_F'}, inplace = True)
    marca_f = marca_f.drop_duplicates()
    
    base = pd.merge(base,marca_f,left_on =['LLAVE_RIESGO','ND'],right_on=['LLAVE_RIESGO','ANTERIOR'],how='left')
    
    #AGREGAR WHERE IN LIST
    
    #pd.DataFrame(base_4.RAMO_PROD.tolist()).isin(ramo_prod_privado).any(axis=1).values
    
    base = base.drop(base[(base.MARCA_NR.values == 'RENOVADA_CANCELADA') & (base.MARCA_F.values == 'RENOVADA')].index)
    base = base.drop(base[(base.MARCA_NR.values == 'NUEVA_CANCELADA') & (base.MARCA_F.values == 'RENOVADA')].index)
    base['PER_INICIO'] = (base['FI_CERTIFICADO'].dt.year)*100 + (base['FI_CERTIFICADO'].dt.month)
    base["RETROACTIVO"] = np.where((((base['MARCA_NR'] == 'NUEVA')|(base['MARCA_NR'] == 'RENOVADA'))&(base['PERIODO_CONTABLE']>base['PER_INICIO'])),'SI','NO')
    base = base.drop(["MARCA_F"], axis = 1)
    
    #AGREGAR WHERE IN LIST
    retroactivo = base.loc[(base['MARCA_NR']=='NUEVA')|(base['MARCA_NR']=='RENOVADA'),['LLAVE_V','RETROACTIVO']].copy()
    retroactivo.rename(columns = {'RETROACTIVO':'RETRO'}, inplace = True)
    retroactivo = retroactivo.drop_duplicates()
    
    base = pd.merge(base,retroactivo,on='LLAVE_V',how='left')
    
#DESDE ACA COMIENZA 'PP_PRIVADO_MES_1'
base_privado = base_privado[base_privado['MARCA_NR']!='']
base_privado['RETROACTIVO']=np.where(base_privado.RETRO.values!='',base_privado['RETRO'],base_privado['RETROACTIVO'])
base_privado['FECHA_IN_CERT']=(base_privado['FI_CERTIFICADO'].dt.year)*100+(base_privado['FI_CERTIFICADO'].dt.month)
base_privado['FECHA_IN_MATR']=(base_privado['FI_POLIZA_MATRIZ'].dt.year)*100+(base_privado['FI_POLIZA_MATRIZ'].dt.month)
base_privado['CONTADOR']==1
base_privado['TIPO_POLIZA']=='I'
base_privado = base_privado.drop(["OT","PN","N","P","INDICADOR","ND","ANTERIOR","RETRO"], axis = 1)
#ELIMINAR CAMPOS CON NUEVOS NOMBRES QUE AUN NO SE DEFINEN, I.E. FEC_INI_POLIZA
base_privado = base_privado[['PERIODO_CONTABLE','SUCURSAL','RAMO','POLIZA','CERTIFICADO','RECIBO','ANEXO','FEC_INIC_POLIZA','FEC_INC_CERT','FEC_FIN_CERT','TIPO_TRANSACCION','COD_TRANSACCION','TIPO_POLIZA','VR_PRIMA_PESOS','VR_PRIMA_MON_ORG','PRIMA_ANUAL','VR_ASEG_ACCESORIOS','VR_ASEG_CASCO','PLACA RIESGO','RETROACTIVO','FECHA_IN_CERT','FECHA_IN_MATR','MARCA','ZONA','CONTADOR']]

#DESDE ACA COMIENZA 'PP_COLECTIVO_MES_1'
base_colectivo = base_colectivo[base_colectivo['MARCA_NR']!='']
base_colectivo['RETROACTIVO']=np.where(base_colectivo.RETRO.values!='',base_colectivo['RETRO'],base_colectivo['RETROACTIVO'])
base_colectivo['FECHA_IN_CERT']=(base_colectivo['FI_CERTIFICADO'].dt.year)*100+(base_colectivo['FI_CERTIFICADO'].dt.month)
base_colectivo['FECHA_IN_MATR']=(base_colectivo['FI_POLIZA_MATRIZ'].dt.year)*100+(base_colectivo['FI_POLIZA_MATRIZ'].dt.month)
base_colectivo['CONTADOR']==1
base_colectivo['TIPO_POLIZA']=='C'
base_colectivo = base_colectivo.drop(["OT","PN","N","P","INDICADOR","ND","ANTERIOR","RETRO"], axis = 1)
#ELIMINAR CAMPOS CON NUEVOS NOMBRES QUE AUN NO SE DEFINEN, I.E. FEC_INI_POLIZA
base_colectivo = base_colectivo[['PERIODO_CONTABLE','SUCURSAL','RAMO','POLIZA','CERTIFICADO','RECIBO','ANEXO','FEC_INIC_POLIZA','FEC_INC_CERT','FEC_FIN_CERT','TIPO_TRANSACCION','COD_TRANSACCION','TIPO_POLIZA','VR_PRIMA_PESOS','VR_PRIMA_MON_ORG','PRIMA_ANUAL','VR_ASEG_ACCESORIOS','VR_ASEG_CASCO','PLACA','RIESGO','RETROACTIVO','FECHA_IN_CERT','FECHA_IN_MATR','MARCA','ZONA','CONTADOR']]

#DESDE ACA COMIENZA 'PP_BANCO_MES_1'
base_banco = base_banco[base_banco['MARCA_NR']!='']
base_banco['FECHA_IN_CERT']=(base_banco['FI_CERTIFICADO'].dt.year)*100+(base_banco['FI_CERTIFICADO'].dt.month)
base_banco['FECHA_IN_MATR']=(base_banco['FI_POLIZA_MATRIZ'].dt.year)*100+(base_banco['FI_POLIZA_MATRIZ'].dt.month)
base_banco['CONTADOR']==1
base_banco['TIPO_POLIZA']=='C'
base_banco['DESC_AGRUP_TIPO']=='VACIO'
base_banco['ZONA']=='BANCO'
base_banco = base_banco.drop(["OT","PN","N","P","INDICADOR","ND","ANTERIOR","RETRO"], axis = 1)
#ELIMINAR CAMPOS CON NUEVOS NOMBRES QUE AUN NO SE DEFINEN, I.E. FEC_INI_POLIZA
base_banco = base_banco[['PERIODO_CONTABLE','SUCURSAL','RAMO','POLIZA','CERTIFICADO','RECIBO','ANEXO','FEC_INIC_POLIZA','FEC_INC_CERT','FEC_FIN_CERT','TIPO_TRANSACCION','COD_TRANSACCION','TIPO_POLIZA','VR_PRIMA_PESOS','VR_PRIMA_MON_ORG','PRIMA_ANUAL','VR_ASEG_ACCESORIOS','VR_ASEG_CASCO','PLACA','RIESGO','RETROACTIVO','FECHA_IN_CERT','FECHA_IN_MATR','MARCA','ZONA','CONTADOR','COBERTURA','DESCUENTO','TIPO','GRUPO','DESC_AGRUP_TIPO','DESCRIPCION','GRUPO_P','MARCA_P','DEPARTAMENTO']]

#DESDE ACA COMIENZA 'PP_COOMEVA_MES_1'
base_coomeva = base_coomeva[base_coomeva['MARCA_NR']!='']
base_coomeva['FECHA_IN_CERT']=(base_coomeva['FI_CERTIFICADO'].dt.year)*100+(base_coomeva['FI_CERTIFICADO'].dt.month)
base_coomeva['FECHA_IN_MATR']=(base_coomeva['FI_POLIZA_MATRIZ'].dt.year)*100+(base_coomeva['FI_POLIZA_MATRIZ'].dt.month)
base_coomeva['CONTADOR']==1
base_coomeva['TIPO_POLIZA']=='C'
base_coomeva = base_coomeva.drop(["OT","PN","N","P","INDICADOR","ND","ANTERIOR","RETRO"], axis = 1)
base_coomeva['ZONA']=np.where(base_coomeva.ZONA.values=='','CALI',base_coomeva['ZONA'])
#ELIMINAR CAMPOS CON NUEVOS NOMBRES QUE AUN NO SE DEFINEN, I.E. FEC_INI_POLIZA
base_coomeva = base_coomeva[['PERIODO_CONTABLE','SUCURSAL','RAMO','POLIZA','CERTIFICADO','RECIBO','ANEXO','FEC_INIC_POLIZA','FEC_INC_CERT','FEC_FIN_CERT','TIPO_TRANSACCION','COD_TRANSACCION','TIPO_POLIZA','VR_PRIMA_PESOS','VR_PRIMA_MON_ORG','PRIMA_ANUAL','VR_ASEG_ACCESORIOS','VR_ASEG_CASCO','PLACA','RIESGO','RETROACTIVO','FECHA_IN_CERT','FECHA_IN_MATR','MARCA','ZONA','CONTADOR']]

for base in bases:
    base['RAMO']=''
    base['RAMO']=np.where(base.RAMO_PROD.values=='6041','AW',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6031','AU',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6032','AX',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6033','AL',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6034','MT',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6035','PM',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6036','CT',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6037','AU',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6038','TI',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6039','PI',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6042','AW',base['RAMO'])
    
    base['RAMO']=np.where(base.RAMO_PROD.values=='6043','MW',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6045','AT',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6046','TT',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6047','TP',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6048','MW',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6060','BV',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='6061','BV',base['RAMO'])
    base['RAMO']=np.where(base.RAMO_PROD.values=='',base['RAMO_PROD'],base['RAMO'])
    base['RECIBO']=np.where(base.RECIBO.values='',0,base['RECIBO'])
    base['COD_TRANSACCION']==0
    base.rename(columns = {'SUCURSAL_PROD':'SUCURSAL','FI_POLIZA_MATRIZ':'FEC_INIC_POLIZA','FI_CERTIFICADO':'FEC_INC_CERT','FF_CERTIFICADO':'FEC_FIN_CERT','TIPO_TRANSAC':'TIPO_TRANSACCION','VR_PRIMA_MN_ORIG':'VR_PRIMA_MON_ORG','VR_PRIMA_ANUAL':'PRIMA_ANUAL','NRO_PLACA':'PLACA','LLAVE_RIESGO':'RIESGO','MARCA_NR':'MARCA'}, inplace = True)
    
bases_privado_colectivo = [base_privado,base_colectivo]
bases_banco_coomeva = [base_banco,base_coomeva]

#%%time

type_dict_canal = {}

canal = pd.read_csv("canal.csv", index_col=0, dtype = type_dict_canal)
canal.head()

for base_pc in bases_privado_colectivo:
    base_pc = pd.merge(base_pc,canal[['CLASIFICACION_MOR','SUCURSAL_FUSION']],left_on ='SUCURSAL_PROD',right_on='SUCURSAL_FUSION',how='left')
    base_pc.rename(columns = {"CLASIFICACION MOR":"CANAL_2"}, inplace = True)
    base_pc.head()

ramo_prod_resumen_privado = ['6031','6032','6033','6035','6036','6037','6060','6061','AU','AL','AX','CT','PM','LM']

#SE AGREGA PERIODO ACA O EN EL COMIENZO?
#PP_PRIVADO_1=BASE_PRIVADO
resumen_privado = base_privado.loc[(base_privado.PERIODO_CONTABLE.values>=periodo-100),['PERIODO_CONTABLE','RAMO_PROD','MARCA_NR',]].copy()
resumen_privado['GRUPO'] = np.where(pd.DataFrame(base_privado.RAMO_PROD.tolist()).isin(ramo_prod_resumen_privado).any(axis=1).values,'AUTOS','MOTOS')
resumen_privado = resumen_privado.groupby(['PERIODO_CONTABLE','GRUPO','MARCA_NR']).agg({'RAMO_PROD':'count'})
resumen_privado.rename(columns={'RAMO_PROD':'CUENTA'},inplace=True)

#FALTA RESUMEN PRIVADO_1

ramo_prod_colectivo_livianos = ['6041','6042','6045','AT','AW','ET','LF']
ramo_prod_colectivo_pesados = ['6039','6047','TP','PE']
ramo_prod_colectivo_taxi = ['6038','6046','TT','TU','TS']

#SE AGREGA PERIODO ACA O EN EL COMIENZO?
resumen_colectivo = base_colectivo.loc[(base_colectivo.PERIODO_CONTABLE.values>=periodo-100),['PERIODO_CONTABLE','RAMO_PROD','MARCA_NR']].copy()
resumen_colectivo['GRUPO'] = ''
resumen_colectivo['GRUPO'] = np.where(pd.DataFrame(base_colectivo.RAMO_PROD.tolist()).isin(ramo_prod_colectivo_livianos).any(axis=1).values,'LIVIANOS',base_colectivo['GRUPO'])
resumen_colectivo['GRUPO'] = np.where(pd.DataFrame(base_colectivo.RAMO_PROD.tolist()).isin(ramo_prod_colectivo_pesados).any(axis=1).values,'PESADOS',base_colectivo['GRUPO'])
resumen_colectivo['GRUPO'] = np.where(pd.DataFrame(base_colectivo.RAMO_PROD.tolist()).isin(ramo_prod_colectivo_taxi).any(axis=1).values,'TAXI',base_colectivo['GRUPO'])
resumen_colectivo = resumen_colectivo.groupby(['PERIODO_CONTABLE','GRUPO','MARCA_NR']).agg({'RAMO_PROD':'count'})
resumen_colectivo.rename(columns={'RAMO_PROD':'CUENTA'},inplace=True)


#FALTA RESUMEN COLECTIVO_1

#SE AGREGA PERIODO ACA O EN EL COMIENZO?
resumen_banco = base_banco.loc[(base_banco.PERIODO_CONTABLE.values>=periodo-100),['PERIODO_CONTABLE','RAMO_PROD','MARCA_NR']].copy()
resumen_banco = resumen_banco.groupby(['PERIODO_CONTABLE','GRUPO','MARCA_NR']).agg({'RAMO_PROD':'count'})
resumen_banco.rename(columns={'RAMO_PROD':'CUENTA'},inplace=True)

#FALTA RESUMEN BANCO_1

#SE AGREGA PERIODO ACA O EN EL COMIENZO?
resumen_coomeva = base_coomeva.loc[(base_coomeva.PERIODO_CONTABLE.values>=periodo-100),['PERIODO_CONTABLE','RAMO_PROD','MARCA_NR']].copy()
resumen_coomeva = resumen_coomeva.groupby(['PERIODO_CONTABLE','GRUPO','MARCA_NR']).agg({'RAMO_PROD':'count'})
resumen_coomeva.rename(columns={'RAMO_PROD':'CUENTA'},inplace=True)

#FALTA RESUMEN COOMEVA_1

ramo_prod_privado_r1 = ['6031','6032','6033','6034','6035','6036','6037','6043','6048','6060','6061','AL','AU','AX','CT','PM','LM','MT','MU','ME','MW']

privado_r1 = base_3_1.loc[((pd.DataFrame(base_3_1.RAMO_PROD.tolist()).isin(ramo_prod_privado_r1).any(axis=1).values)&(base_3_1.SUCURSAL_PROD!=177)),['RAMO_PROD','POLIZA','CERTIFICADO','FI_CERTIFICADO','FF_CERTIFICADO','NRO_PLACA','PLACA_VIG']].copy()
privado_r1 = privado_r1.drop_duplicates()

ramo_prod_colectivo_r1 = ['AT','AW','PE','TP','TT','TS','TU','6041','6042','6045','6046','6047','6038','6039','LO','MO','PO','TO','LF','MF','900753']
not_sucursal_prod_colectivo_r1 = [177,214]

colectivo_r1 = base_3_1.loc[((pd.DataFrame(base_3_1.RAMO_PROD.tolist()).isin(ramo_prod_colectivo_r1).any(axis=1).values)&(~base_3_1.SUCURSAL_PROD.isin(not_sucursal_prod_colectivo_r1))),['RAMO_PROD','POLIZA','CERTIFICADO','FI_CERTIFICADO','FF_CERTIFICADO','NRO_PLACA','PLACA_VIG']].copy()
colectivo_r1 = privado_r1.drop_duplicates()

banco_r1 = base_3_1.loc[base_3_1.SUCURSAL_PROD.values==214,['RAMO_PROD','POLIZA','CERTIFICADO','FI_CERTIFICADO','FF_CERTIFICADO','NRO_PLACA','PLACA_VIG']].copy()
banco_r1 = banco_r1.drop_duplicates()

coomeva_r1 = base_3_1.loc[base_3_1.SUCURSAL_PROD.values==177,['RAMO_PROD','POLIZA','CERTIFICADO','FI_CERTIFICADO','FF_CERTIFICADO','NRO_PLACA','PLACA_VIG']].copy()
coomeva_r1 = banco_r1.drop_duplicates()

marca_nr = ['NUEVA','RENOVADA']

pp_1_list=[]
#revisar
for base in bases:
    pp_1 = base_r.loc[(pd.DataFrame(pp_1.RAMO_PROD.tolist()).isin(marca_nr).any(axis=1).values),['RAMO_PROD','POLIZA','CERTIFICADO','FI_CERTIFICADO','FF_CERTIFICADO','NRO_PLACA','PLACA_VIG','MARCA_NR','VR_PRIMA_ANUAL','VR_ASEG_CASCO']].copy()
    pp_1 = pp_1.drop_duplicates()
    pp_1 = pp_1.sort_values(['PLACA_VIG','MARCA_NR'],ascending = (False,False))
    pp_1['RANK'] = pp_1.groupby('PLACA_VIG').cumcount()+1
    pp_1 = pp_1.loc[pp_1.RANK.values==1,:]
    pp_1_list.append(pp_1)

pp_1_privado=pp_1_list[0]
pp_1_colectivo=pp_1_list[1]
pp_1_banco=pp_1_list[2]
pp_1_coomeva=pp_1_list[3]
    
privado = pd.merge(privado_r1,pp_1_privado,on=['PLACA_VIG'],how="left")
privado = privado[privado['MARCA_NR']!='']

colectivo = pd.merge(colectivo_r1,pp_1_colectivo,on=['PLACA_VIG'],how="left")
colectivo = colectivo[colectivo['MARCA_NR']!='']

banco = pd.merge(r1,pp_1_banco,on=['PLACA_VIG'],how="left")
banco = banco[banco['MARCA_NR']!='']

coomeva = pd.merge(r1,pp_1_coomeva,on=['PLACA_VIG'],how="left")
coomeva = coomeva[coomeva['MARCA_NR']!='']

# %%
pi = 201812
difp=[365,366]
tipo_transac_base=[4,12]
ramo_prod_banco_livianos=['LO','LF','TO']
ramo_prod_banco_motos=['MO','MF']
ramo_prod_coomeva_livianos=['AT','AW']
ramo_prod_coomeva_motos=['MW','MU','MT','ME']
ramo_prod_privado_livianos=['6031','6032','6033','6035','6036','6037','AU','AL','AX','CT','PM','LM','6060','6061']
ramo_prod_colectivo_livianos=['6041','6042','6045','AT','AW','ET']
ramo_prod_colectivo_pesados=['6039','6047','TP','PE']
ramo_prod_colectivo_taxis=['6038','6046','TT','TU','TS']

cod_departamento_banco_medellin=['5','27']
cod_departamento_banco_baranquilla=['8','13','20','23','44','47','70','88'] 
cod_departamento_banco_bogota=['11','25']
cod_departamento_banco_centro=['15','18','41','50','73','85','91','94','95','97','99']
cod_departamento_banco_eje_cafetero=['17','63','66']
cod_departamento_banco_cali=['19','52','76','86']
cod_departamento_banco_buscaramanga=['54','68','81']

app_banco=base_banco.loc[base_banco.PER_INICIO>{pi},:].copy()
app_coomeva=base_coomeva.loc[base_coomeva.PER_INICIO>{pi},:].copy()
app_aui=base_privado.loc[base_privado.PER_INICIO>{pi},:].copy()
app_auc=base_colectivo.loc[base_colectivo.PER_INICIO>{pi},].copy()

app_banco['GRUPO']=np.where((pd.DataFrame(app_banco.RAMO_PROD.tolist()).isin(ramo_prod_banco_livianos).any(axis=1).values)|((app_banco.RAMO_PROD.values=='900753')&(app_banco.TIPO_RIESGO.values==1))|((app_banco.RAMO_PROD.values=='900753')&(app_banco.TIPO_RIESGO.values==''))|((app_banco.RAMO_PROD.values=='900753')&(app_banco.TIPO_RIESGO.values==4)),'LIVIANOS',app_banco['GRUPO'])
app_banco['GRUPO']=np.where((app_banco.RAMO_PROD.values=='PO')|((app_banco.RAMO_PROD.values=='900753')&(app_banco.TIPO_RIESGO.values==2)),'PESADOS',app_banco['GRUPO'])
app_banco['GRUPO']=np.where(((app_banco.RAMO_PROD.values=='900753')&(app_banco.TIPO_RIESGO.values==3))|(pd.DataFrame(app_banco.RAMO_PROD.tolist()).isin(ramo_prod_motos).any(axis=1).values),'MOTOS',app_banco['GRUPO'])
app_banco=app_banco[['POLIZA','PERIODO_CONTABLE','SUCURSAL_PROD','PER_INICIO','DIFERENCIA','RAMO_PROD','ZONA_TOMADOR','VR_ASEG_CASCO','VR_PRIMA_ANUAL','VR_PRIMA_PESOS','FECHA_IN_MATR','CONTADOR','GRUPO','MARCA_NR','TIPO_RIESGO','INTERMEDIARIO_LIDE','TIPO_RIESGO']]

app_coomeva['GRUPO']=np.where(((pd.DataFrame(app_coomeva.RAMO_PROD.tolist()).isin(ramo_prod_coomeva_livianos).any(axis=1).values)|((app_coomeva.RAMO_PROD.values=='900753')&(app_coomeva.TIPO_RIESGO.values==1))|((app_coomeva.RAMO_PROD.values=='900753')&(app_coomeva.TIPO_RIESGO.values==''))),'LIVIANOS',app_coomeva['GRUPO'])
app_coomeva['GRUPO']=np.where(((app_coomeva.RAMO_PROD.values=='TP')|((app_coomeva.RAMO_PROD.values=='900753')&(app_coomeva.TIPO_RIESGO.values==2))),'PESADOS',app_coomeva['GRUPO'])
app_coomeva['GRUPO']=np.where(((pd.DataFrame(app_coomeva.RAMO_PROD.tolist()).isin(ramo_prod_coomeva_motos).any(axis=1).values)|((app_coomeva.RAMO_PROD.values=='900753')&(app_coomeva.TIPO_RIESGO.values==3))),'MOTO',app_coomeva['GRUPO'])
app_coomeva['GRUPO']=np.where(((app_coomeva.RAMO_PROD.values=='TT')|((app_coomeva.RAMO_PROD.values=='900753')&(app_coomeva.TIPO_RIESGO.values==4))),'TAXIS',app_coomeva['GRUPO'])

app_aui['GRUPO']=np.where(pd.DataFrame(app_aui.RAMO_PROD.tolist()).isin(ramo_prod_privado_livianos).any(axis=1).values,'LIVIANOS','MOTOS')

app_auc['GRUPO']=np.where(((pd.DataFrame(app_auc.RAMO_PROD.tolist()).isin(ramo_prod_colectivo_livianos).any(axis=1).values)|((app_auc.RAMO_PROD.values=='900753')&(app_auc.TIPO_RIESGO.values==1))|((app_auc.RAMO_PROD.values=='900753')&(app_auc.TIPO_RIESGO.values==''))),'LIVIANOS',app_auc['GRUPO'])
app_auc['GRUPO']=np.where(((pd.DataFrame(app_auc.RAMO_PROD.tolist()).isin(ramo_prod.colectivo_pesados).any(axis=1).values)|((app_auc.RAMO_PROD.values=='900753')&(app_auc.TIPO_RIESGO.values==4))),'PESADOS',app_auc['GRUPO'])
app_auc['GRUPO']=np.where(((pd.DataFrame(app_auc.RAMO_PROD.tolist()).isin(ramo_prod_colectivo_taxis).any(axis=1).values)|()),'TAXIS',app_auc['GRUPO'])

apps=[app_banco,app_coomeva,app_aui,app_auc]

for app in apps:
    app['DIFP']=(app['FI_DOCUMENTO']-app['FI_CERTIFICADO'])dt.days
    app=app.drop([(pd.DataFrame(app.TIPO_TRANSAC.tolist()).isin(tipo_transac_base).any(axis=1).values)&(pd.DataFrame(app.DIFP.tolist()).isin(difp).any(axis=1).values)&(base.VR_PRIMA_MN_ORIG.values==0)].index)

    #DIFERENCIA
    '''C=COMPRESS(PERIODO_CONTABLE);
    AC=SUBSTR(C,1,4); STRING
    MC=SUBSTR(C,5,2); STRING
    AI=YEAR(FI_CERTIFICADO); INT/DATE
    MI=MONTH(FI_CERTIFICADO) INT/DATE
    DIFERENCIA=12*(AC-AI)+(MC-MI)+1'''

    app['DIFERENCIA']=''
    app['DIFERENCIA']=np.where(pd.DataFrame(app.MARCA_NR.tolist()).isin(marca_nr).any(axis=1).values,0,app['DIFERENCIA'])
    
    #existe LA COLUMNA ZONA TOMADOR

    app['ZONA_TOMADOR']=np.where(pd.DataFrame(app.COD_DEPARTAMENTO.tolist()).isin(cod_departamento_banco_medellin).any(axis=1).values,'MEDELLIN',app['ZONA_TOMADOR'])
    app['ZONA_TOMADOR']=np.where(pd.DataFrame(app.COD_DEPARTAMENTO.tolist()).isin(cod_departamento_banco_barranquilla).any(axis=1).values,'BARRANQUILLA',app['ZONA_TOMADOR'])
    app['ZONA_TOMADOR']=np.where(pd.DataFrame(app.COD_DEPARTAMENTO.tolist()).isin(cod_departamento_banco_bogota).any(axis=1).values,'BOGOTA',app['ZONA_TOMADOR'])
    app['ZONA_TOMADOR']=np.where(pd.DataFrame(app.COD_DEPARTAMENTO.tolist()).isin(cod_departamento_banco_centro).any(axis=1).values,'CENTRO',app['ZONA_TOMADOR'])
    app['ZONA_TOMADOR']=np.where(pd.DataFrame(app.COD_DEPARTAMENTO.tolist()).isin(cod_departamento_banco_eje_cafetero).any(axis=1).values,'EJE_CAFETERO',app['ZONA_TOMADOR'])
    app['ZONA_TOMADOR']=np.where(pd.DataFrame(app.COD_DEPARTAMENTO.tolist()).isin(cod_departamento_banco_cali).any(axis=1).values,'CALI',app['ZONA_TOMADOR'])
    app['ZONA_TOMADOR']=np.where(pd.DataFrame(app.COD_DEPARTAMENTO.tolist()).isin(cod_departamento_banco_bucaramanga).any(axis=1).values,'BUCARAMANGA',app['ZONA_TOMADOR'])
    
    
    app=pd.merge(app,forma_pago_act,on=['RAMO_PROD','POLIZA'],how='left')
    app=pd.merge(app,zona,left_on=['SUCURSAL_PROD'],right_on=['SUCURSAL'],how='left')

app_banco['FORMA_PAGO']=np.where(app_banco.FORMA_PAGO.values=='','MENSUAL',app_banco['FORMA_PAGO'])
app_coomeva['FORMA_PAGO']=np.where(app_coomeva.FORMA_PAGO.values=='','MENSUAL',app_coomeva['FORMA_PAGO'])
app_aui['FORMA_PAGO']=np.where(app_aui.FORMA_PAGO.values=='','ANUAL',app_aui['FORMA_PAGO'])
app_aui['ZONA']=np.where(app_aui.ZONA.values=='','BOGOTA NORTE',app_aui['ZONA'])
app_auc['FORMA_PAGO']=np.where(app_auc.FORMA_PAGO.values=='','ANUAL',app_auc['FORMA_PAGO'])
app_auc['ZONA']=np.where(app_auc.ZONA.values=='','BOGOTA NORTE',app_auc['ZONA'])

# %%
comercial=pd.concat([base_colectivo,base_banco,base_coomeva],ignore_index=True)
pp_comercial=comercial.loc[comercial.PERIODO_CONTABLE.values=={periodo},['PERIODO_CONTABLE','MARCA_NR','CONTADOR']].copy()
pp_comercial=pp_comercial.groupby(['PERIODO_CONTABLE','MARCA_NR']).agg({'CONTADOR':'sum'})
pp_comercial.rename(columns={'CONTADOR':'CUENTA'},inplace=True)

#revisar pivote
pp_privado_final=base_privado.loc[base_privado.PERIODO_CONTABLE.values=={periodo},['PERIODO_CONTABLE','MARCA_NR','CONTADOR']].copy()
pp_privado_final=base_privado.groupby(['PERIODO_CONTABLE','MARCA_NR']).agg({'CONTADOR':'sum'})
pp_comercial.rename(columns={'CONTADOR':'CUENTA'},inplace=True)
